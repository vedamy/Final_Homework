# %% [markdown]
# # WEEK-14 Homework Assignment

# %% [markdown]
# The CalCOFI data set represents the longest (1949-present) and most complete (more than 50,000 sampling stations) time series
# of oceanographic and larval fish data in the world. It includes abundance data on the larvae of over 250 species of fish; larval
# length frequency data and egg abundance data on key commercial species; and oceanographic and plankton data.
#
#
# The  CalCOFI organization was formed in 1949 to study the ecological aspects of the sardine population collapse off California.
# CalCOFI conducts quarterly cruises off southern & central California, collecting a suite of hydrographic and biological data on
# station and underway. Data collected at depths down to 500 m include: temperature, salinity, oxygen, phosphate, silicate,
# nitrate and nitrite, chlorophyll, transmissometer, PAR, C14 primary productivity, phytoplankton biodiversity, zooplankton
# biomass, and zooplankton biodiversity.

# %% [markdown]
# Resource: https://www.kaggle.com/sohier/calcofi

# %% [markdown]
# 1.	Perform pre-processing on the full dataset here: https://www.kaggle.com/sohier/calcofi
#
# 2.	Perform feature selection (decide what columns should be included in your analysis). How did you figure out what features were important?
#
# 3.	Perform multiple linear regression on the dataset. Be sure to display the final resulting equation with the coefficients and intercept in markdown.
#
# 4.	Which regression approach had the “best” performance? Be sure to compare it to what you did last week.
#
# 5.	Work with the diabetes dataset to perform multiple logistic regression.
#
# 6.	What are the other ways to assess the performance of the model besides accuracy? What approach makes the most sense with the diabetes dataset? Why?
#
# 7.	Tune your model to improve performance based on the performance metric you identified in question 6. Look at the documentation for logistic regression in statsmodel and/or sklearn and see if you can tune the model performance based on available parameters. Please note: data scientists need to constantly learn new approaches to optimizing models. This is one way of doing that.
#
# 8.	Is the KNN model or the multiple logistic regression model more performant for the diabetes dataset? How can you tell?

# %%
# import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression

# %%
cast_df=pd.read_csv("A:/launch_code_STL/Final_Homework/week-13/cast.csv", index_col=False, low_memory=False)

# %%
cast_df.shape
# Out:
# (34404, 61)

# %%
cast_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34404 entries, 0 to 34403
# Data columns (total 61 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Cst_Cnt      34404 non-null  int64
#  1   Cruise_ID    34404 non-null  object
#  2   Cruise       34404 non-null  int64
#  3   Cruz_Sta     34404 non-null  int64
#  4   DbSta_ID     34404 non-null  int64
#  5   Cast_ID      34404 non-null  object
#  6   Sta_ID       34404 non-null  object
#  7   Quarter      34404 non-null  int64
#  8   Sta_Code     34404 non-null  object
#  9   Distance     19714 non-null  float64
#  10  Date         34404 non-null  object
#  11  Year         34404 non-null  int64
#  12  Month        34404 non-null  int64
#  13  Julian_Date  34404 non-null  int64
#  14  Julian_Day   34404 non-null  int64
#  15  Time         34080 non-null  object
#  16  Lat_Dec      34404 non-null  float64
#  17  Lat_Deg      34404 non-null  int64
#  18  Lat_Min      34404 non-null  float64
#  19  Lat_Hem      34404 non-null  object
#  20  Lon_Dec      34404 non-null  float64
#  21  Lon_Deg      34404 non-null  int64
#  22  Lon_Min      34404 non-null  float64
#  23  Lon_Hem      34404 non-null  object
#  24  Rpt_Line     34404 non-null  float64
#  25  St_Line      34404 non-null  float64
#  26  Ac_Line      34404 non-null  float64
#  27  Rpt_Sta      34404 non-null  float64
#  28  St_Station   34404 non-null  float64
#  29  Ac_Sta       34404 non-null  float64
#  30  Bottom_D     32123 non-null  float64
#  31  Secchi       5263 non-null   float64
#  32  ForelU       2077 non-null   float64
#  33  Ship_Name    32714 non-null  object
#  34  Ship_Code    34404 non-null  object
#  35  Data_Type    34404 non-null  object
#  36  Order_Occ    9954 non-null   float64
#  37  Event_Num    34401 non-null  float64
#  38  Cruz_Leg     1464 non-null   float64
#  39  Orig_Sta_ID  34404 non-null  object
#  40  Data_Or      18275 non-null  object
#  41  Cruz_Num     34404 non-null  object
#  42  IntChl       12203 non-null  float64
#  43  IntC14       2129 non-null   float64
#  44  Inc_Str      2133 non-null   object
#  45  Inc_End      2133 non-null   object
#  46  PST_LAN      2117 non-null   object
#  47  Civil_T      2116 non-null   object
#  48  TimeZone     4782 non-null   float64
#  49  Wave_Dir     12558 non-null  float64
#  50  Wave_Ht      12098 non-null  float64
#  51  Wave_Prd     11634 non-null  float64
#  52  Wind_Dir     32928 non-null  float64
#  53  Wind_Spd     32725 non-null  float64
#  54  Barometer    19063 non-null  float64
#  55  Dry_T        19071 non-null  float64
#  56  Wet_T        18989 non-null  float64
#  57  Wea          26807 non-null  float64
#  58  Cloud_Typ    9920 non-null   float64
#  59  Cloud_Amt    11882 non-null  float64
#  60  Visibility   9507 non-null   float64
# dtypes: float64(32), int64(11), object(18)
# memory usage: 16.0+ MB

# %%
#checking for variable types
cast_df.dtypes.value_counts()
# Out:
# float64    32
# object     18
# int64      11
# dtype: int64

# %%
# Numerical data
num_df = cast_df.describe()
num_df
# Out:
#             Cst_Cnt         Cruise      Cruz_Sta      DbSta_ID       Quarter  \
# count  34404.000000   34404.000000  3.440400e+04  3.440400e+04  34404.000000
# mean   17202.500000  197406.030781  1.974061e+13  9.330342e+06      2.366556
# std     9931.723667    1974.562207  1.974557e+11  2.217993e+06      1.091894
# min        1.000000  194903.000000  1.949030e+13  1.016800e+05      1.000000
# 25%     8601.750000  195701.000000  1.957011e+13  8.100430e+06      1.000000
# 50%    17202.500000  196912.000000  1.969121e+13  9.000800e+06      2.000000
# 75%    25803.250000  198809.000000  1.988091e+13  1.067032e+07      3.000000
# max    34404.000000  201611.000000  2.016111e+13  1.767030e+07      4.000000
#
#            Distance         Year         Month   Julian_Date    Julian_Day  \
# count  19714.000000  34404.00000  34404.000000  34404.000000  34404.000000
# mean    -116.135017   1974.00218      5.835397  27017.612313    161.366236
# std      117.282768     19.74668      3.326775   6900.075983    100.761217
# min    -1920.150000   1949.00000      1.000000  17957.000000      2.000000
# 25%     -169.801500   1957.00000      3.000000  20832.750000     75.000000
# 50%      -83.570000   1969.00000      6.000000  25532.000000    157.000000
# 75%      -29.470000   1988.00000      9.000000  32400.000000    247.000000
# max       -0.141000   2016.00000     12.000000  41116.000000    354.000000
#
#        ...      Wave_Prd      Wind_Dir      Wind_Spd     Barometer  \
# count  ...  11634.000000  32928.000000  32725.000000  19063.000000
# mean   ...      6.440863     27.067602     11.135951   1016.243702
# std    ...      2.295422      9.456406      6.823464      8.818816
# min    ...      0.000000      0.000000      0.000000    101.400000
# 25%    ...      5.000000     26.000000      6.000000   1013.700000
# 50%    ...      6.000000     31.000000     10.000000   1016.300000
# 75%    ...      8.000000     33.000000     15.000000   1019.100000
# max    ...     50.000000     37.000000     71.000000   1112.600000
#
#               Dry_T         Wet_T           Wea    Cloud_Typ     Cloud_Amt  \
# count  19071.000000  18989.000000  26807.000000  9920.000000  11882.000000
# mean      16.261989     14.414635      1.324729     5.636895      4.995624
# std        2.728030      2.630224      1.162603     2.173354      3.106067
# min        1.700000      1.800000      0.000000     0.000000      0.000000
# 25%       14.400000     12.600000      1.000000     6.000000      2.000000
# 50%       16.100000     14.200000      1.000000     6.000000      6.000000
# 75%       17.900000     16.000000      2.000000     7.000000      8.000000
# max       43.100000     58.000000      9.000000     9.000000      9.000000
#
#         Visibility
# count  9507.000000
# mean      6.803092
# std       1.534078
# min       0.000000
# 25%       6.000000
# 50%       7.000000
# 75%       8.000000
# max       9.000000
#
# [8 rows x 43 columns]

# %%
# include=['O'] pulls out the objects dtypes attributes from our data 
cat_df = cast_df.describe(include=['O'])  #Categorical data
cat_df
# Out:
#                 Cruise_ID                         Cast_ID       Sta_ID  \
# count               34404                           34404        34404
# unique                645                           34404         2634
# top     1988-08-29-C-32NM  19-4903CR-HY-060-0930-05400560  090.0 045.0
# freq                  433                               1          347
#
#        Sta_Code        Date      Time Lat_Hem Lon_Hem              Ship_Name  \
# count     34404       34404     34080   34404   34404                  32714
# unique        7        6466      2730       1       1                     33
# top          ST  09/05/1988  00:00:00       N       W  RV DAVID STARR JORDAN
# freq      15117          30       130   34404   34404                   7140
#
#        Ship_Code Data_Type Orig_Sta_ID Data_Or  Cruz_Num              Inc_Str  \
# count      34404     34404       34404   18275     34404                 2133
# unique        33         5        4190       4       378                  115
# top         31JD        HY     90   45    3101  FRONTS88  12/30/1899 12:10:00
# freq        8037     21495         128   18235       433                  117
#
#                     Inc_End              PST_LAN              Civil_T
# count                  2133                 2117                 2116
# unique                  200                   79                  181
# top     12/30/1899 18:00:00  12/30/1899 12:01:00  12/30/1899 17:47:00
# freq                     48                   68                   32

# %% [markdown]
# ### Encoding the Categorical Features
#
# We can do this in two ways :
# 1.By using pd.get_dummies()
# 2.By using, sklearn’s in-built function of OneHotEncoder and LabelEncoder

# %%
# Using One-Hot Encoding
cat_df = pd.get_dummies(cat_df['Ship_Name'],drop_first=True)
cat_df.head()
# Out:
#         7140  32714  RV DAVID STARR JORDAN
# count      0      1                      0
# unique     0      0                      0
# top        0      0                      1
# freq       1      0                      0

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

"""Categorical data to be converted to numeric data"""
# LabelEncoder
LabelEncoder = LabelEncoder()
integer_encoder = LabelEncoder.fit_transform(cat_df['Ship_Name'].values)
print(integer_encoder)

# # OneHotEncoder
# onehot_encoder= OneHotEncoder(sparse=False, dtype='int')    
# integer_encoder = integer_encoder.reshape(len(integer_encoder), 1)
# onehot_encoder= onehot_encoder.fit_transform(integer_encoder)
# print(onehot_encoder)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ship_Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3196/2081537405.py in <module>
#       4 # LabelEncoder
#       5 LabelEncoder = LabelEncoder()
# ----> 6 integer_encoder = LabelEncoder.fit_transform(cat_df['Ship_Name'].values)
#       7 print(integer_encoder)
#       8
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Ship_Name'

# %%
bottle_df = pd.read_csv("A:/launch_code_STL/Final_Homework/week-13/bottle.csv", index_col=False, low_memory=False )

# %% [markdown]
# ### Data Preprocessing:
# Preparing Data for modeling

# %%
bottle_df.shape
# Out:
# (864863, 74)

# %%
bottle_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864863 entries, 0 to 864862
# Data columns (total 74 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Cst_Cnt              864863 non-null  int64
#  1   Btl_Cnt              864863 non-null  int64
#  2   Sta_ID               864863 non-null  object
#  3   Depth_ID             864863 non-null  object
#  4   Depthm               864863 non-null  int64
#  5   T_degC               853900 non-null  float64
#  6   Salnty               817509 non-null  float64
#  7   O2ml_L               696201 non-null  float64
#  8   STheta               812174 non-null  float64
#  9   O2Sat                661274 non-null  float64
#  10  Oxy_µmol/Kg          661268 non-null  float64
#  11  BtlNum               118667 non-null  float64
#  12  RecInd               864863 non-null  int64
#  13  T_prec               853900 non-null  float64
#  14  T_qual               23127 non-null   float64
#  15  S_prec               817509 non-null  float64
#  16  S_qual               74914 non-null   float64
#  17  P_qual               673755 non-null  float64
#  18  O_qual               184676 non-null  float64
#  19  SThtaq               65823 non-null   float64
#  20  O2Satq               217797 non-null  float64
#  21  ChlorA               225272 non-null  float64
#  22  Chlqua               639166 non-null  float64
#  23  Phaeop               225271 non-null  float64
#  24  Phaqua               639170 non-null  float64
#  25  PO4uM                413317 non-null  float64
#  26  PO4q                 451786 non-null  float64
#  27  SiO3uM               354091 non-null  float64
#  28  SiO3qu               510866 non-null  float64
#  29  NO2uM                337576 non-null  float64
#  30  NO2q                 529474 non-null  float64
#  31  NO3uM                337403 non-null  float64
#  32  NO3q                 529933 non-null  float64
#  33  NH3uM                64962 non-null   float64
#  34  NH3q                 808299 non-null  float64
#  35  C14As1               14432 non-null   float64
#  36  C14A1p               12760 non-null   float64
#  37  C14A1q               848605 non-null  float64
#  38  C14As2               14414 non-null   float64
#  39  C14A2p               12742 non-null   float64
#  40  C14A2q               848623 non-null  float64
#  41  DarkAs               22649 non-null   float64
#  42  DarkAp               20457 non-null   float64
#  43  DarkAq               840440 non-null  float64
#  44  MeanAs               22650 non-null   float64
#  45  MeanAp               20457 non-null   float64
#  46  MeanAq               840439 non-null  float64
#  47  IncTim               14437 non-null   object
#  48  LightP               18651 non-null   float64
#  49  R_Depth              864863 non-null  float64
#  50  R_TEMP               853900 non-null  float64
#  51  R_POTEMP             818816 non-null  float64
#  52  R_SALINITY           817509 non-null  float64
#  53  R_SIGMA              812007 non-null  float64
#  54  R_SVA                812092 non-null  float64
#  55  R_DYNHT              818206 non-null  float64
#  56  R_O2                 696201 non-null  float64
#  57  R_O2Sat              666448 non-null  float64
#  58  R_SIO3               354099 non-null  float64
#  59  R_PO4                413325 non-null  float64
#  60  R_NO3                337411 non-null  float64
#  61  R_NO2                337584 non-null  float64
#  62  R_NH4                64982 non-null   float64
#  63  R_CHLA               225276 non-null  float64
#  64  R_PHAEO              225275 non-null  float64
#  65  R_PRES               864863 non-null  int64
#  66  R_SAMP               122006 non-null  float64
#  67  DIC1                 1999 non-null    float64
#  68  DIC2                 224 non-null     float64
#  69  TA1                  2084 non-null    float64
#  70  TA2                  234 non-null     float64
#  71  pH2                  10 non-null      float64
#  72  pH1                  84 non-null      float64
#  73  DIC Quality Comment  55 non-null      object
# dtypes: float64(65), int64(5), object(4)
# memory usage: 488.3+ MB

# %%
#checking for variable types
bottle_df.dtypes.value_counts()
# Out:
# float64    65
# int64       5
# object      4
# dtype: int64

# %%
# Numerical data
bottle_df.describe()
# Out:
#              Cst_Cnt        Btl_Cnt         Depthm         T_degC  \
# count  864863.000000  864863.000000  864863.000000  853900.000000
# mean    17138.790958  432432.000000     226.831951      10.799677
# std     10240.949817  249664.587269     316.050259       4.243825
# min         1.000000       1.000000       0.000000       1.440000
# 25%      8269.000000  216216.500000      46.000000       7.680000
# 50%     16848.000000  432432.000000     125.000000      10.060000
# 75%     26557.000000  648647.500000     300.000000      13.880000
# max     34404.000000  864863.000000    5351.000000      31.140000
#
#               Salnty         O2ml_L         STheta          O2Sat  \
# count  817509.000000  696201.000000  812174.000000  661274.000000
# mean       33.840350       3.392468      25.819394      57.103779
# std         0.461843       2.073256       1.167787      37.094137
# min        28.431000      -0.010000      20.934000      -0.100000
# 25%        33.488000       1.360000      24.965000      21.100000
# 50%        33.863000       3.440000      25.996000      54.400000
# 75%        34.196900       5.500000      26.646000      97.600000
# max        37.034000      11.130000     250.784000     214.100000
#
#          Oxy_µmol/Kg         BtlNum  ...         R_CHLA        R_PHAEO  \
# count  661268.000000  118667.000000  ...  225276.000000  225275.000000
# mean      148.808694      10.497426  ...       0.450225       0.198599
# std        90.187533       6.189688  ...       1.208566       0.376539
# min        -0.434900       0.000000  ...      -0.010000      -3.890000
# 25%        60.915470       5.000000  ...       0.050000       0.050000
# 50%       151.064150      10.000000  ...       0.160000       0.110000
# 75%       240.379600      16.000000  ...       0.390000       0.230000
# max       485.701800      25.000000  ...      66.110000      65.300000
#
#               R_PRES         R_SAMP         DIC1         DIC2          TA1  \
# count  864863.000000  122006.000000  1999.000000   224.000000  2084.000000
# mean      228.395694     162.071521  2153.239714  2168.148330  2256.055845
# std       319.456731      85.722796   112.995202   154.852332    34.844435
# min         0.000000       0.000000  1948.850000  1969.440000  2181.570000
# 25%        46.000000     200.000000  2028.330000  2008.977500  2230.322500
# 50%       126.000000     206.000000  2170.640000  2265.885000  2244.325000
# 75%       302.000000     214.000000  2253.810000  2315.525000  2278.505000
# max      5458.000000     424.000000  2367.800000  2364.420000  2434.900000
#
#                TA2        pH2        pH1
# count   234.000000  10.000000  84.000000
# mean   2278.858803   7.948570   7.910983
# std      58.496495   0.021216   0.077666
# min    2198.150000   7.923100   7.618300
# 25%    2229.062500   7.931475   7.898675
# 50%    2247.505000   7.946650   7.928850
# 75%    2316.452500   7.963300   7.955100
# max    2437.000000   7.988300   8.047700
#
# [8 rows x 70 columns]

# %%
# include=['O'] pulls out the objects dtypes attributes from our data 
bottle_df.describe(include=['O'])  #Categorical data
# Out:
#              Sta_ID                                Depth_ID  \
# count        864863                                  864863
# unique         2634                                  864850
# top     090.0 045.0  20-16045S-MX-110-2018-06330900-0010A-3
# freq          10043                                       2
#
#                      IncTim                                DIC Quality Comment
# count                 14437                                                 55
# unique                  199                                                 37
# top     12/30/1899 05:45:00  CTD Bottle Misfire; DIC sample compromised.  C...
# freq                    325                                                  9

# %%
# checking for the columns in Bottle Dataset
print(bottle_df.columns)
# Out:
# Index(['Cst_Cnt', 'Btl_Cnt', 'Sta_ID', 'Depth_ID', 'Depthm', 'T_degC',
#        'Salnty', 'O2ml_L', 'STheta', 'O2Sat', 'Oxy_µmol/Kg', 'BtlNum',
#        'RecInd', 'T_prec', 'T_qual', 'S_prec', 'S_qual', 'P_qual', 'O_qual',
#        'SThtaq', 'O2Satq', 'ChlorA', 'Chlqua', 'Phaeop', 'Phaqua', 'PO4uM',
#        'PO4q', 'SiO3uM', 'SiO3qu', 'NO2uM', 'NO2q', 'NO3uM', 'NO3q', 'NH3uM',
#        'NH3q', 'C14As1', 'C14A1p', 'C14A1q', 'C14As2', 'C14A2p', 'C14A2q',
#        'DarkAs', 'DarkAp', 'DarkAq', 'MeanAs', 'MeanAp', 'MeanAq', 'IncTim',
#        'LightP', 'R_Depth', 'R_TEMP', 'R_POTEMP', 'R_SALINITY', 'R_SIGMA',
#        'R_SVA', 'R_DYNHT', 'R_O2', 'R_O2Sat', 'R_SIO3', 'R_PO4', 'R_NO3',
#        'R_NO2', 'R_NH4', 'R_CHLA', 'R_PHAEO', 'R_PRES', 'R_SAMP', 'DIC1',
#        'DIC2', 'TA1', 'TA2', 'pH2', 'pH1', 'DIC Quality Comment'],
#       dtype='object')

# %%
#Counts and percentage of null values 
dictionary = {
    "NullCount":bottle_df.isnull().sum().sort_values(ascending=False),
    "NullPercent":bottle_df.isnull().sum().sort_values(ascending=False)/len(bottle_df)*100
}

na_df = pd.DataFrame(dictionary)
na_df.columns = ['NullCount','NullPercent']
na_df[(na_df['NullCount'] > 0)].reset_index()
# Out:
#                   index  NullCount  NullPercent
# 0                   pH2     864853    99.998844
# 1   DIC Quality Comment     864808    99.993641
# 2                   pH1     864779    99.990287
# 3                  DIC2     864639    99.974100
# 4                   TA2     864629    99.972944
# ..                  ...        ...          ...
# 61               C14A1q      16258     1.879835
# 62               C14A2q      16240     1.877754
# 63               R_TEMP      10963     1.267600
# 64               T_prec      10963     1.267600
# 65               T_degC      10963     1.267600
#
# [66 rows x 3 columns]

# %%
pct_null = bottle_df.isnull().sum() / len(bottle_df)
missing_features = pct_null[pct_null > 0.20].index
bottle_df.drop(missing_features, axis=1, inplace=True)
df = bottle_df
df.head()
# Out:
#    Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 0        1        1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
# 1        1        2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3
# 2        1        3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7
# 3        1        4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3
# 4        1        5  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7
#
#    Depthm  T_degC  Salnty  O2ml_L  STheta  RecInd  ...  MeanAq  R_Depth  \
# 0       0   10.50  33.440     NaN  25.649       3  ...     9.0      0.0
# 1       8   10.46  33.440     NaN  25.656       3  ...     9.0      8.0
# 2      10   10.46  33.437     NaN  25.654       7  ...     9.0     10.0
# 3      19   10.45  33.420     NaN  25.643       3  ...     9.0     19.0
# 4      20   10.45  33.421     NaN  25.643       7  ...     9.0     20.0
#
#    R_TEMP  R_POTEMP  R_SALINITY  R_SIGMA  R_SVA  R_DYNHT  R_O2  R_PRES
# 0   10.50     10.50      33.440    25.64  233.0     0.00   NaN       0
# 1   10.46     10.46      33.440    25.65  232.5     0.01   NaN       8
# 2   10.46     10.46      33.437    25.65  232.8     0.02   NaN      10
# 3   10.45     10.45      33.420    25.64  234.1     0.04   NaN      19
# 4   10.45     10.45      33.421    25.64  234.0     0.04   NaN      20
#
# [5 rows x 26 columns]

# %%
print(df.nunique() / df.shape[0] * 100 )
# Out:
# Cst_Cnt         3.977971
# Btl_Cnt       100.000000
# Sta_ID          0.304557
# Depth_ID       99.998497
# Depthm          0.372198
# T_degC          1.601063
# Salnty          1.688360
# O2ml_L          0.751564
# STheta          4.205059
# RecInd          0.000578
# T_prec          0.000347
# S_prec          0.000231
# NH3q            0.000231
# C14A1q          0.000231
# C14A2q          0.000231
# DarkAq          0.000231
# MeanAq          0.000231
# R_Depth         0.372198
# R_TEMP          0.325948
# R_POTEMP        0.330341
# R_SALINITY      0.414401
# R_SIGMA         0.508520
# R_SVA           0.607495
# R_DYNHT         0.213675
# R_O2            0.100710
# R_PRES          0.384801
# dtype: float64

# %%
df.columns
# Out:
# Index(['Cst_Cnt', 'Btl_Cnt', 'Sta_ID', 'Depth_ID', 'Depthm', 'T_degC',
#        'Salnty', 'O2ml_L', 'STheta', 'RecInd', 'T_prec', 'S_prec', 'NH3q',
#        'C14A1q', 'C14A2q', 'DarkAq', 'MeanAq', 'R_Depth', 'R_TEMP', 'R_POTEMP',
#        'R_SALINITY', 'R_SIGMA', 'R_SVA', 'R_DYNHT', 'R_O2', 'R_PRES'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Cst_Cnt         int64
# Btl_Cnt         int64
# Sta_ID         object
# Depth_ID       object
# Depthm          int64
# T_degC        float64
# Salnty        float64
# O2ml_L        float64
# STheta        float64
# RecInd          int64
# T_prec        float64
# S_prec        float64
# NH3q          float64
# C14A1q        float64
# C14A2q        float64
# DarkAq        float64
# MeanAq        float64
# R_Depth       float64
# R_TEMP        float64
# R_POTEMP      float64
# R_SALINITY    float64
# R_SIGMA       float64
# R_SVA         float64
# R_DYNHT       float64
# R_O2          float64
# R_PRES          int64
# dtype: object

# %%
# Removing the missing values
# print(df.dropna())
df_new=df.dropna()
df_new
# Out:
#         Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 2160         71     2161  044.0 048.5  19-4904CR-HY-087-0606-04400485-0000B-3
# 2162         71     2163  044.0 048.5  19-4904CR-HY-087-0606-04400485-0010A-7
# 2163         71     2164  044.0 048.5  19-4904CR-HY-087-0606-04400485-0015A-3
# 2164         71     2165  044.0 048.5  19-4904CR-HY-087-0606-04400485-0020A-7
# 2165         71     2166  044.0 048.5  19-4904CR-HY-087-0606-04400485-0030A-7
# ...         ...      ...          ...                                     ...
# 864855    34403   864856  093.3 120.0  20-1611SR-MX-313-2053-09331200-0440A-3
# 864856    34403   864857  093.3 120.0  20-1611SR-MX-313-2053-09331200-0500A-7
# 864857    34403   864858  093.3 120.0  20-1611SR-MX-313-2053-09331200-0521A-3
# 864859    34404   864860  093.4 026.4  20-1611SR-MX-310-2239-09340264-0002A-3
# 864860    34404   864861  093.4 026.4  20-1611SR-MX-310-2239-09340264-0005A-3
#
#         Depthm  T_degC   Salnty  O2ml_L    STheta  RecInd  ...  MeanAq  \
# 2160         0  10.300  33.0300   5.900  25.36400       3  ...     9.0
# 2162        10  10.290  32.9510   6.040  25.30400       7  ...     9.0
# 2163        15  10.290  32.9900   6.060  25.33500       3  ...     9.0
# 2164        20  10.330  33.0050   6.040  25.33900       7  ...     9.0
# 2165        30  10.390  33.0540   6.010  25.36800       7  ...     9.0
# ...        ...     ...      ...     ...       ...     ...  ...     ...
# 864855     440   6.312  34.1563   0.718  26.85639       3  ...     9.0
# 864856     500   5.993  34.2160   0.456  26.94518       7  ...     9.0
# 864857     521   5.818  34.2382   0.366  26.98477       3  ...     9.0
# 864859       2  18.744  33.4083   5.805  23.87072       3  ...     9.0
# 864860       5  18.692  33.4150   5.796  23.88911       3  ...     9.0
#
#         R_Depth  R_TEMP  R_POTEMP  R_SALINITY  R_SIGMA  R_SVA  R_DYNHT  R_O2  \
# 2160        0.0   10.30     10.30      33.030   25.360  260.2    0.000  5.90
# 2162       10.0   10.29     10.29      32.951   25.300  266.1    0.020  6.04
# 2163       15.0   10.29     10.29      32.990   25.330  263.3    0.040  6.06
# 2164       20.0   10.33     10.33      33.005   25.330  262.9    0.050  6.04
# 2165       30.0   10.39     10.39      33.054   25.360  260.4    0.070  6.01
# ...         ...     ...       ...         ...      ...    ...      ...   ...
# 864855    440.0    6.31      6.27      34.156   26.856  125.3    1.026  0.72
# 864856    500.0    5.99      5.95      34.216   26.945  117.5    1.107  0.46
# 864857    521.0    5.82      5.77      34.238   26.985  113.9    1.123  0.37
# 864859      2.0   18.74     18.74      33.408   23.871  402.5    0.008  5.81
# 864860      5.0   18.69     18.69      33.415   23.889  400.8    0.020  5.80
#
#         R_PRES
# 2160         0
# 2162        10
# 2163        15
# 2164        20
# 2165        30
# ...        ...
# 864855     444
# 864856     504
# 864857     525
# 864859       2
# 864860       5
#
# [584277 rows x 26 columns]

# %%
# check if any duplicates are present in the data
print('COUNT OF DUPLICATES:  {}'.format(df_new.duplicated().sum()))
# Out:
# COUNT OF DUPLICATES:  0

# %% [markdown]
# 2. Perform feature selection (decide what columns should be included in your analysis). How did you figure out what features were important?

# %%
# Feature Selection is a method of selecting features from the data and help in  improving the model performance.
# its very important to understand the dataset before using it to train the model.
# Feature selection helps to get rid of noise in the model and also redundant fratures that are adding noise, and features that 
# are strongly correlated, which breaks the assumptions of certain models and thus impact model performance.

# %%
# After removing the missing data we are left with only 26 rows. Out of these 26 rows there are some features that are repeats 
# for example T_Prec and S_Prec are the units of Temperature and salinity, in the same way we have redundant features like, 
# R_Depth, R_TEMP, R_POTEMP, R_SALINITY, R_SIGMA, R_SVA, R_O2 which are all falls under repeats and we need to get rid of all 
# these redundant features, to do that we need to drop all these features which are adding noise.

# feature_df = df_new.drop(['RecInd', 'T_prec', 'S_prec', 'R_Depth', 'R_TEMP', 'R_POTEMP', 'R_SALINITY', 'R_SIGMA', 'R_SVA', 'R_O2'], axis=1)


feature_df = df_new.drop(columns=['RecInd', 'T_prec', 'S_prec', 'R_Depth', 'R_TEMP', 'R_POTEMP', 'R_SALINITY', 'R_SIGMA', 'R_SVA', 'R_O2'])
print(feature_df)
# Out:
#         Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 2160         71     2161  044.0 048.5  19-4904CR-HY-087-0606-04400485-0000B-3
# 2162         71     2163  044.0 048.5  19-4904CR-HY-087-0606-04400485-0010A-7
# 2163         71     2164  044.0 048.5  19-4904CR-HY-087-0606-04400485-0015A-3
# 2164         71     2165  044.0 048.5  19-4904CR-HY-087-0606-04400485-0020A-7
# 2165         71     2166  044.0 048.5  19-4904CR-HY-087-0606-04400485-0030A-7
# ...         ...      ...          ...                                     ...
# 864855    34403   864856  093.3 120.0  20-1611SR-MX-313-2053-09331200-0440A-3
# 864856    34403   864857  093.3 120.0  20-1611SR-MX-313-2053-09331200-0500A-7
# 864857    34403   864858  093.3 120.0  20-1611SR-MX-313-2053-09331200-0521A-3
# 864859    34404   864860  093.4 026.4  20-1611SR-MX-310-2239-09340264-0002A-3
# 864860    34404   864861  093.4 026.4  20-1611SR-MX-310-2239-09340264-0005A-3
#
#         Depthm  T_degC   Salnty  O2ml_L    STheta  NH3q  C14A1q  C14A2q  \
# 2160         0  10.300  33.0300   5.900  25.36400   9.0     9.0     9.0
# 2162        10  10.290  32.9510   6.040  25.30400   9.0     9.0     9.0
# 2163        15  10.290  32.9900   6.060  25.33500   9.0     9.0     9.0
# 2164        20  10.330  33.0050   6.040  25.33900   9.0     9.0     9.0
# 2165        30  10.390  33.0540   6.010  25.36800   9.0     9.0     9.0
# ...        ...     ...      ...     ...       ...   ...     ...     ...
# 864855     440   6.312  34.1563   0.718  26.85639   4.0     9.0     9.0
# 864856     500   5.993  34.2160   0.456  26.94518   4.0     9.0     9.0
# 864857     521   5.818  34.2382   0.366  26.98477   4.0     9.0     9.0
# 864859       2  18.744  33.4083   5.805  23.87072   4.0     9.0     9.0
# 864860       5  18.692  33.4150   5.796  23.88911   4.0     9.0     9.0
#
#         DarkAq  MeanAq  R_DYNHT  R_PRES
# 2160       9.0     9.0    0.000       0
# 2162       9.0     9.0    0.020      10
# 2163       9.0     9.0    0.040      15
# 2164       9.0     9.0    0.050      20
# 2165       9.0     9.0    0.070      30
# ...        ...     ...      ...     ...
# 864855     9.0     9.0    1.026     444
# 864856     9.0     9.0    1.107     504
# 864857     9.0     9.0    1.123     525
# 864859     9.0     9.0    0.008       2
# 864860     9.0     9.0    0.020       5
#
# [584277 rows x 16 columns]

# %%
# df=feature_df.reset_index()
index=feature_df.index
number_of_rows = len(index)
number_of_rows
# Out:
# 584277

# %%
# Now we figure out which of these are closely correlated using correlation method
feature_df.corr()
# Out:
#           Cst_Cnt   Btl_Cnt    Depthm    T_degC    Salnty    O2ml_L    STheta  \
# Cst_Cnt  1.000000  0.999280 -0.145098  0.050597 -0.184224  0.120051 -0.086138
# Btl_Cnt  0.999280  1.000000 -0.144196  0.051463 -0.180236  0.118402 -0.085407
# Depthm  -0.145098 -0.144196  1.000000 -0.665523  0.554513 -0.586301  0.665445
# T_degC   0.050597  0.051463 -0.665523  1.000000 -0.476207  0.786966 -0.962517
# Salnty  -0.184224 -0.180236  0.554513 -0.476207  1.000000 -0.813839  0.680948
# O2ml_L   0.120051  0.118402 -0.586301  0.786966 -0.813839  1.000000 -0.886233
# STheta  -0.086138 -0.085407  0.665445 -0.962517  0.680948 -0.886233  1.000000
# NH3q    -0.206501 -0.213333  0.010000  0.007898  0.025469  0.015255  0.001102
# C14A1q  -0.003455 -0.003333  0.002183 -0.004995  0.004450 -0.004136  0.005744
# C14A2q  -0.003455 -0.003333  0.002183 -0.004995  0.004450 -0.004136  0.005744
# DarkAq  -0.003455 -0.003333  0.002183 -0.004995  0.004450 -0.004136  0.005744
# MeanAq  -0.003455 -0.003333  0.002183 -0.004995  0.004450 -0.004136  0.005744
# R_DYNHT -0.135646 -0.135351  0.923377 -0.793921  0.653395 -0.759263  0.812089
# R_PRES  -0.144808 -0.143900  0.999994 -0.664109  0.553294 -0.584476  0.663900
#
#              NH3q    C14A1q    C14A2q    DarkAq    MeanAq   R_DYNHT    R_PRES
# Cst_Cnt -0.206501 -0.003455 -0.003455 -0.003455 -0.003455 -0.135646 -0.144808
# Btl_Cnt -0.213333 -0.003333 -0.003333 -0.003333 -0.003333 -0.135351 -0.143900
# Depthm   0.010000  0.002183  0.002183  0.002183  0.002183  0.923377  0.999994
# T_degC   0.007898 -0.004995 -0.004995 -0.004995 -0.004995 -0.793921 -0.664109
# Salnty   0.025469  0.004450  0.004450  0.004450  0.004450  0.653395  0.553294
# O2ml_L   0.015255 -0.004136 -0.004136 -0.004136 -0.004136 -0.759263 -0.584476
# STheta   0.001102  0.005744  0.005744  0.005744  0.005744  0.812089  0.663900
# NH3q     1.000000 -0.000381 -0.000381 -0.000381 -0.000381 -0.008576  0.009863
# C14A1q  -0.000381  1.000000  1.000000  1.000000  1.000000  0.003324  0.002175
# C14A2q  -0.000381  1.000000  1.000000  1.000000  1.000000  0.003324  0.002175
# DarkAq  -0.000381  1.000000  1.000000  1.000000  1.000000  0.003324  0.002175
# MeanAq  -0.000381  1.000000  1.000000  1.000000  1.000000  0.003324  0.002175
# R_DYNHT -0.008576  0.003324  0.003324  0.003324  0.003324  1.000000  0.922279
# R_PRES   0.009863  0.002175  0.002175  0.002175  0.002175  0.922279  1.000000

# %%
# From the above correlation method some of the features were very strongly correlated which creates bias in the model. 
# lets drop the olumns which are closely correlated.

to_drop = ['Cst_Cnt', 'Btl_Cnt', 'C14A1q', 'C14A2q', 'DarkAq', 'MeanAq']
feature_subset = feature_df.drop(to_drop, axis=1)
print(feature_subset.head())
# Out:
#            Sta_ID                                Depth_ID  Depthm  T_degC  \
# 2160  044.0 048.5  19-4904CR-HY-087-0606-04400485-0000B-3       0   10.30
# 2162  044.0 048.5  19-4904CR-HY-087-0606-04400485-0010A-7      10   10.29
# 2163  044.0 048.5  19-4904CR-HY-087-0606-04400485-0015A-3      15   10.29
# 2164  044.0 048.5  19-4904CR-HY-087-0606-04400485-0020A-7      20   10.33
# 2165  044.0 048.5  19-4904CR-HY-087-0606-04400485-0030A-7      30   10.39
#
#       Salnty  O2ml_L  STheta  NH3q  R_DYNHT  R_PRES
# 2160  33.030    5.90  25.364   9.0     0.00       0
# 2162  32.951    6.04  25.304   9.0     0.02      10
# 2163  32.990    6.06  25.335   9.0     0.04      15
# 2164  33.005    6.04  25.339   9.0     0.05      20
# 2165  33.054    6.01  25.368   9.0     0.07      30

# %%
# We need to extract Year and Month from Depth_ID column 
# Below we have original format which is of object type
# Depth_ID: [Century]-[YY][MM][ShipCode]-[CastType][Julian Day]-[CastTime]-[Line][Sta][Depth][Bottle]-[Rec_Ind]
# Depth_ID Format: 19-4903CR-HY-060-0930-05400560-0020A-7

feature_subset['Year'] = (feature_subset['Depth_ID'].str.split('-', expand=True)[0] + \
                feature_subset['Depth_ID'].str.split('-', expand=True)[1]). \
                map(lambda x: str(x)[:4])
feature_subset['Month'] = (feature_subset['Depth_ID'].str.split('-', expand=True)[1]). \
                 map(lambda x: str(x)[2:4])
                 
feature_subset[['Depth_ID','Year','Month']].head(10)
# Out:
#                                     Depth_ID  Year Month
# 2160  19-4904CR-HY-087-0606-04400485-0000B-3  1949    04
# 2162  19-4904CR-HY-087-0606-04400485-0010A-7  1949    04
# 2163  19-4904CR-HY-087-0606-04400485-0015A-3  1949    04
# 2164  19-4904CR-HY-087-0606-04400485-0020A-7  1949    04
# 2165  19-4904CR-HY-087-0606-04400485-0030A-7  1949    04
# 2166  19-4904CR-HY-087-0606-04400485-0031A-3  1949    04
# 2167  19-4904CR-HY-087-0606-04400485-0047A-3  1949    04
# 2168  19-4904CR-HY-087-0606-04400485-0050A-7  1949    04
# 2169  19-4904CR-HY-087-0606-04400485-0064A-3  1949    04
# 2170  19-4904CR-HY-087-0606-04400485-0075A-7  1949    04

# %% [markdown]
# #### Resource: https://new.data.calcofi.org/index.php/database/calcofi-database/bottle-field-descriptions

# %%
print(feature_subset)
# Out:
#              Sta_ID                                Depth_ID  Depthm  T_degC  \
# 2160    044.0 048.5  19-4904CR-HY-087-0606-04400485-0000B-3       0  10.300
# 2162    044.0 048.5  19-4904CR-HY-087-0606-04400485-0010A-7      10  10.290
# 2163    044.0 048.5  19-4904CR-HY-087-0606-04400485-0015A-3      15  10.290
# 2164    044.0 048.5  19-4904CR-HY-087-0606-04400485-0020A-7      20  10.330
# 2165    044.0 048.5  19-4904CR-HY-087-0606-04400485-0030A-7      30  10.390
# ...             ...                                     ...     ...     ...
# 864855  093.3 120.0  20-1611SR-MX-313-2053-09331200-0440A-3     440   6.312
# 864856  093.3 120.0  20-1611SR-MX-313-2053-09331200-0500A-7     500   5.993
# 864857  093.3 120.0  20-1611SR-MX-313-2053-09331200-0521A-3     521   5.818
# 864859  093.4 026.4  20-1611SR-MX-310-2239-09340264-0002A-3       2  18.744
# 864860  093.4 026.4  20-1611SR-MX-310-2239-09340264-0005A-3       5  18.692
#
#          Salnty  O2ml_L    STheta  NH3q  R_DYNHT  R_PRES  Year Month
# 2160    33.0300   5.900  25.36400   9.0    0.000       0  1949    04
# 2162    32.9510   6.040  25.30400   9.0    0.020      10  1949    04
# 2163    32.9900   6.060  25.33500   9.0    0.040      15  1949    04
# 2164    33.0050   6.040  25.33900   9.0    0.050      20  1949    04
# 2165    33.0540   6.010  25.36800   9.0    0.070      30  1949    04
# ...         ...     ...       ...   ...      ...     ...   ...   ...
# 864855  34.1563   0.718  26.85639   4.0    1.026     444  2016    11
# 864856  34.2160   0.456  26.94518   4.0    1.107     504  2016    11
# 864857  34.2382   0.366  26.98477   4.0    1.123     525  2016    11
# 864859  33.4083   5.805  23.87072   4.0    0.008       2  2016    11
# 864860  33.4150   5.796  23.88911   4.0    0.020       5  2016    11
#
# [584277 rows x 12 columns]

# %%
# Now that we extracted year and month we can get rid of Depth_ID column and we can drop Sta_ID as well we have no use here

drop_cols = ['Sta_ID', 'Depth_ID', 'Depthm']
df_norm = feature_subset.drop(drop_cols, axis=1)  #  data for normalization
df_scale = df_norm.copy(deep=True) 
print(df_norm.head())
# Out:
#       T_degC  Salnty  O2ml_L  STheta  NH3q  R_DYNHT  R_PRES  Year Month
# 2160   10.30  33.030    5.90  25.364   9.0     0.00       0  1949    04
# 2162   10.29  32.951    6.04  25.304   9.0     0.02      10  1949    04
# 2163   10.29  32.990    6.06  25.335   9.0     0.04      15  1949    04
# 2164   10.33  33.005    6.04  25.339   9.0     0.05      20  1949    04
# 2165   10.39  33.054    6.01  25.368   9.0     0.07      30  1949    04

# %%
df_norm["T_degC"].value_counts()
# Out:
# 9.020     789
# 9.200     784
# 8.820     784
# 9.300     780
# 9.060     778
#          ...
# 12.619      1
# 11.912      1
# 8.323       1
# 6.272       1
# 18.692      1
# Name: T_degC, Length: 8899, dtype: int64

# %% [markdown]
# 3. Perform multiple linear regression on the dataset. Be sure to display the final resulting equation with the coefficients and intercept in markdown.

# %%
sns.scatterplot(x='Salnty',
               y='STheta',
               data=df_norm,
               hue="T_degC")

plt.show()

# %%
# Modeling with two explanatory variables

mdl_temp_vs_both = ols("T_degC ~ Salnty + STheta", data=df_norm).fit()
print(mdl_temp_vs_both.params)
# Out:
# Intercept    36.074528
# Salnty        3.092504
# STheta       -5.030820
# dtype: float64

# %%
from itertools import product

Salnty = np.arange(20, 251, 2)
STheta = np.arange(25, 40, 2)

p = product(Salnty, STheta)

explanatory_data = pd.DataFrame(p,
                                columns=["Salnty","STheta"])

prediction_data = explanatory_data.assign(T_degC = mdl_temp_vs_both.predict(explanatory_data))
print(prediction_data)
# Out:
#      Salnty  STheta      T_degC
# 0        20      25  -27.845894
# 1        20      27  -37.907534
# 2        20      29  -47.969175
# 3        20      31  -58.030815
# 4        20      33  -68.092456
# ..      ...     ...         ...
# 923     250      31  653.245149
# 924     250      33  643.183508
# 925     250      35  633.121868
# 926     250      37  623.060228
# 927     250      39  612.998587
#
# [928 rows x 3 columns]

# %%
sns.scatterplot(x='Salnty',
               y='STheta',
               data=df_norm,
               hue="T_degC")

sns.scatterplot(x="Salnty",
                y="STheta",
                data=prediction_data,
                hue="T_degC",
                legend=False,
                marker="s")

plt.show()
# Out:
# C:\Users\rsagu\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:137: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#Including an Interaction

# %%
mdl_temp_vs_both_inter = ols("T_degC ~ Salnty * STheta", data=df_norm).fit()
print(mdl_temp_vs_both_inter.params)
# Out:
# Intercept       -198.862182
# Salnty             9.991581
# STheta             4.268567
# Salnty:STheta     -0.273019
# dtype: float64

# %%
Salnty = np.arange(20, 251, 5)
STheta = np.arange(28, 38, 2)

p = product(Salnty, STheta)

explanatory_data = pd.DataFrame(p,
                                columns=["Salnty","STheta"])

prediction_data = explanatory_data.assign(T_degC = mdl_temp_vs_both.predict(explanatory_data))
print(prediction_data)
# Out:
#      Salnty  STheta      T_degC
# 0        20      28  -42.938355
# 1        20      30  -52.999995
# 2        20      32  -63.061636
# 3        20      34  -73.123276
# 4        20      36  -83.184916
# ..      ...     ...         ...
# 230     250      28  668.337610
# 231     250      30  658.275969
# 232     250      32  648.214329
# 233     250      34  638.152688
# 234     250      36  628.091048
#
# [235 rows x 3 columns]

# %%
sns.scatterplot(x="Salnty",
                y="T_degC",
                data=df_norm,
                hue="T_degC")

sns.scatterplot(x="Salnty",
                y="T_degC",
                data=prediction_data,
                hue="T_degC",
                marker="s")
plt.legend(loc='best')
plt.show()

# %%
# Features Salinity, Temperature are selected

X = np.array(df_norm['Salnty']).reshape(-1, 1).astype(float)
y = np.array(df_norm['T_degC']).reshape(-1, 1).astype(float)

# %%
# Split data as 80% train set and 20% test set
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
# Linear Regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

lr_df = LinearRegression()
lr_df.fit(X_train, y_train)
y_pred = lr_df.predict(X_test)
acc_score = lr_df.score(X_test, y_test)
# print(y_pred)
print("Linear Regression Model Accuracy Score: " + "{:.1%}".format(acc_score))
print("R2 Score: " +"{:.3}".format(r2_score(y_test, y_pred)))
# Out:
# [[ 8.65958164]
#  [10.77228335]
#  [12.86734245]
#  ...
#  [ 9.18444908]
#  [11.85289278]
#  [12.12194247]]
# Linear Regression Model Accuracy Score: 22.3%
# R2 Score: 0.223

# %% [markdown]
# ### Multiple Linear Regression

# %%
mlr_df = LinearRegression()
mlr_df = mlr_df.fit(X_train, y_train) 
y_pred = mlr_df.predict(X_train)                                      # predict Multi linear Reg model
rmse = np.sqrt(mean_squared_error(y_train, mlr_df.predict(X_train)))
print("Intercept: ",mlr_df.intercept_)       
print("Coefficient: ",mlr_df.coef_) 
print("RMSE Score for Test set: " +"{:.2}".format(rmse))
print("R2 Score for Test set: " +"{:.3}".format(r2_score(y_train, y_pred)))
# Out:
# Intercept:  [160.13897062]
# Coefficient:  [[-4.41065074]]
# RMSE Score for Test set: 3.7
# R2 Score for Test set: 0.228

# %%
from sklearn.model_selection import cross_val_score, cross_val_predict

cross_val_score(mlr_df, X, y, cv=10, scoring = 'r2').mean()
# Out:
# 0.22887165161967543

# %%
mlr_df.score(X_train, y_train)
# Out:
# 0.22762839229264353

# %%
np.sqrt(-cross_val_score(mlr_df, 
                X_train, 
                y_train, 
                cv=10, 
                scoring = 'neg_mean_squared_error')).mean()
# Out:
# 3.7412489680992365

# %%
# Plot a graph to show Multiple Linear Regression Model
import operator
import matplotlib as mpl
mpl.rcParams['agg.path.chunksize'] = 10000
plt.scatter(X_train, y_train, s=100)

# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(X_train,y_pred), key=sort_axis)
X_test, y_pred = zip(*sorted_zip)
plt.plot(X_train, y_train, color='g')
plt.xlabel('Salinity')
plt.ylabel('Temperature')
plt.show()

# %% [markdown]
# ### Normalization

# %%
from sklearn.preprocessing import StandardScaler
df_scale = StandardScaler().fit_transform(df_scale)

#  create dataframe
df_norm = pd.DataFrame(df_scale, index=df_norm.index, columns=df_norm.columns)

# %%
df_norm.corr()

#  Drop columns with mode = "0.0".  No impact on correlation
for i in df_norm.columns.tolist():
    if (df_norm[i].mode()[0] == 0.0):
        print(' - ',i,df_norm[i].mode()[0])
        df_norm = df_norm.drop(i,axis=1)

#  Create correlation dataframe
df_corr = pd.DataFrame(columns=['Attributes','Correlation'])
df_corr.Attributes = df_norm.corr()['Salnty'].sort_values(ascending=False).index
df_corr.Correlation = df_norm.corr()['Salnty'].sort_values(ascending=False).values
print(df_corr)
# Out:
#   Attributes  Correlation
# 0     Salnty     1.000000
# 1     STheta     0.680948
# 2    R_DYNHT     0.653395
# 3     R_PRES     0.553294
# 4       NH3q     0.025469
# 5      Month    -0.010479
# 6       Year    -0.196825
# 7     T_degC    -0.476207
# 8     O2ml_L    -0.813839

# %%
# T_degC  Salnty  O2ml_L  STheta  NH3q  R_DYNHT  R_PRES  Year Month

# %%
mlr_df = df_norm[['T_degC', 'Salnty', 'STheta', 'NH3q', 'R_DYNHT', 'R_PRES']]
mlr_df.head()
# Out:
#         T_degC    Salnty    STheta      NH3q   R_DYNHT    R_PRES
# 2160 -0.120466 -1.796177 -0.465918  0.118916 -1.156868 -0.717287
# 2162 -0.122814 -1.967834 -0.525472  0.118916 -1.105465 -0.686039
# 2163 -0.122814 -1.883092 -0.494703  0.118916 -1.054062 -0.670416
# 2164 -0.113422 -1.850499 -0.490732  0.118916 -1.028360 -0.654792
# 2165 -0.099334 -1.744028 -0.461948  0.118916 -0.976957 -0.623545

# %%
mlr_df.shape
# Out:
# (584277, 6)

# %%
# mlr_df = mlr_df[:][:500]      # lets take limit for speed regression calculating
# mlr_df.head()

# %%
mlr_df.isnull().sum()
# Out:
# T_degC     0
# Salnty     0
# STheta     0
# NH3q       0
# R_DYNHT    0
# R_PRES     0
# dtype: int64

# %%
mlr_df.fillna(method='ffill', axis=0, inplace=True)

# %%
from statsmodels.formula.api import ols

salnty_vs_temp = ols("Salnty ~ T_degC +", data = mlr_df)
salnty_vs_temp = salnty_vs_temp.fit()
print(salnty_vs_temp.params)
# Out:
# Intercept    1.405364e-15
# T_degC      -4.762075e-01
# dtype: float64

# %%
# Features Salinity, Temperature are selected

X = np.array(mlr_df['Salnty']).reshape(-1, 1).astype(float)
y = np.array(mlr_df['T_degC']).reshape(-1, 1).astype(float)

# %%
# Split data as 80% train set and 20% test set
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
# Linear Regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

mlr_df = LinearRegression()
mlr_df.fit(X_train, y_train)
y_pred = mlr_df.predict(X_test)
acc_score = mlr_df.score(X_test, y_test)
print("Linear Regression Model Accuracy Score: " + "{:.1%}".format(acc_score))
print("R2 Score: " +"{:.3}".format(r2_score(y_test, y_pred)))
# Out:
# Linear Regression Model Accuracy Score: 22.3%
# R2 Score: 0.223

# %%
mlr_df = LinearRegression()
mlr_df = mlr_df.fit(X_train, y_train) 
y_pred = mlr_df.predict(X_train)                                      # predict Multi linear Reg model
rmse = np.sqrt(mean_squared_error(y_train, mlr_df.predict(X_train)))
print("Intercept: ",mlr_df.intercept_)       
print("Coefficient: ",mlr_df.coef_) 
print("RMSE Score for Test set: " +"{:.2}".format(rmse))
print("R2 Score for Test set: " +"{:.3}".format(r2_score(y_train, y_pred)))
# Out:
# Intercept:  [-0.0009115]
# Coefficient:  [[-0.47660294]]
# RMSE Score for Test set: 0.88
# R2 Score for Test set: 0.228

# %%
from sklearn.model_selection import cross_val_score, cross_val_predict

cross_val_score(mlr_df, X, y, cv=10, scoring = 'r2').mean()
# Out:
# 0.22887165161968254

# %%
mlr_df.score(X_train, y_train)
# Out:
# 0.22762839229264376

# %%
np.sqrt(-cross_val_score(mlr_df, 
                X_train, 
                y_train, 
                cv=10, 
                scoring = 'neg_mean_squared_error')).mean()
# Out:
# 0.8784287995092386

# %%
# Plot a graph to show Multiple Linear Regression Model
import operator
import matplotlib as mpl
mpl.rcParams['agg.path.chunksize'] = 10000
plt.scatter(X_train, y_train, s=100)

# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(X_train,y_pred), key=sort_axis)
X_test, y_pred = zip(*sorted_zip)
plt.plot(X_train, y_train, color='g')
plt.show()
