# %% [markdown]
# # Week-19 Homework Assignment

# %% [markdown]
# 1.	Create a study guide for all the supervised learning models we have gone over. Include information about how the algorithms work, how they are evaluated, and any other information you deem necessary. Use your own words. Do NOT copy mine or that of articles we have read.

# %% [markdown]
# #### supervised learning models:
# With supervised learning task, we can generate a model or predict an output based on input values.
#  In machine learning models the output of the model is typically called a label, target variable, or response variable or dependent variable.
#  The inputs into the model are called features or predictors or independent variable.
#
# The algorithm "learns" the optimal model by studying a training set of data that consists of several obsevations,
# or instances, each of which contains values for both features and its labels.here, the supervised learning algorithm acts as
# a function that takes training data as input and produces a model as its output.

# %% [markdown]
# The most popular Python library for machine learning is the Scikit-Learn (sklearn) package. Scikit-Learn provides functions for creating supervised learning models, as well as for performing unsupervised learning tasks,also provides tools for working and preparing data in creating models.
# scikit-learn makes it very easy to try different models, since the Train-Test-Split/Instantiate/Fit/Predict pattern applies to all the classifiers and regressors.

# %% [markdown]
# Supervised learning models are divided into Classification and Regression problems based on whether the target values are
# continuous or categorical.
# Classification, when the target values are discrete classes For example, Predicting whether the loan is at 'high risk' or
# 'low risk'. In class example like predicting the patient as diabetic or not diabetic.
#
# Regression, when the target values are continuous, real numbers. For example, Predicting a credit score, predicting the sale
# price of a home.

# %% [markdown]
# #### K-Nearest Neighbors(KNN)
# K-Nearest Neighbors(KNN) is a simple algorithm, used to predict the label of any data point by looking at the K.
# 'K' in KNN is a parameter that refers to the number of nearset neighbors to include in the majority voting process. It is
# mostly used for classification problems.

# %% [markdown]
# steps involved are:
# 1. import all the necessary libraries from scikit-learn
#
# from sklearn.neighbors import KNeighborsClassifier
#
# 2. Instantiate the model, and set the number of neighbors
#
# knn = KNeighborsClassifier(n_neighbors=?)
#
# 3. Fit the model to the training set, the labeled data
#
# knn.fit()
#
# 4. Predict the label of an unlabeled data point(new data)
#
# knn.predict()

# %% [markdown]
# After prediction we need to test the model performance, to measure its performance we need a metric.
# Generally in classification problems we use accuracy as a performance metric.
# The classifier is trained on training set, generally we use train_test_split to split the data into training set and
# test set and then predictions are made on the test set and then compared with the known labels.
# The accuracy of the predictions is then computed.

# %% [markdown]
# #### Regression:
# In regression tasks, the target value is a continuously varying variable, like the price of a house.
#
# #### Linear Regression
# A linear regression model uses the features to generate predictions for the countinous/real-valued label.
# The model parameters are calculated by a learning algorithm to generate the model that provides the best fit for the given
# data. The learning algorithm measures the quality of the fit using the sum of squared errors loss function.
#
# 1.To start with, we need to create features and target variables in distinct arrays, X and y.
# Using the .values attribute returns numpy arrays or using .to_numpy.
#
# 2. We will now split the dataset into training and test sets, using an 80/20 split.
#
# 3.Instantiate sklearn.linear_model.LinearRegression
#
# 4.Fit the model by passing in the data and target.
#
# 5.The trained model will contain two new attributes: intercept_ and coef_.
# The intercept_ attribute contains the optimal value of the fitted model and coef_ attribute contains a list of values of
# other parameters.

# %% [markdown]
# For classification models, score() returns the model's accuracy on the provided dataset.
# For regression models, score() returns the model's r-squared score, as calculated on the provided dataset.
# The r-squared score is a number between 0 and 1 that can be interpretted as the proportion of the variance of the response variable

# %% [markdown]
# #### Cross-validation
# Cross-validation is an important step in evaluating a model. It maximizes the amount of data that is used to train
# the model, the model is trained, and also tested on that data.
#
# we use scikit-learn's cross-validation, import cross_val_score from sklearn.model_selection.
# We do this by splitting the dataset into groups, or folds. As the dataset is split into 5 folds,
# this process is called 5-fold cross validation, if k-folds are used it is called k-fold CV.
# while using cross-validation, it is important to remember that if we use more folds, the more computationally expensive
# it will be.

# %% [markdown]
# #### To test how good your model is?
# Accuracy is not useful in all the cases, particularly when dealing with class imbalance problems. For example,
# in spam detection where  99% of emails are real and only 1% are SPAM. There comes confusion_matrix into picture
# which gives the summary of predictive performance, True Positive, True Negative, False Negative, False Positive.
# Also, there are several other important metrics we can easily calculate from the confusion matrix.
# Precision, which is the number of true positives, divided by the total number to true positives and false positives.
# Recall, which is the number of true positives, divided by the total number of true positives and false negatives.
# Recall is also called sensitivity, or true positive rate.
#
# To evaluate the performance of binary classifiers, we use confusion matrix and generate a classification report.
# Import classification_report and confusion_matrix from sklearn.metrics. Then, create training and test sets, instantiate
# the model, then fit the model on the training set and predict the labels on the test set. Lastly, compute and print the
# confusion matrix and classification report using the confusion_matrix() and classification_report() functions.

# %% [markdown]
# #### Logistic regression
# Logistic regression is a linear classification method based on probabilty. It can be used in multi-class
# classification problems, as well as in binary clasiffication problems.
#
# 1.We use the LogisticRegression class from Scikit-Learn to create the classification model, will start with extracting the
# feature and label arrays from the dataset, Before creating the model, we can roughly ckeck the probability of actual values
# using numpy.mean() function.
#
# 2.Next split the data into training and test sets, now we use Scikit-Learn to create our logistic regression classifier and
# then print the parameters(intercept_ and coef_) for our optimal model.
#
# 3.Then, model's score() method to used to calculate the accuracy on the training and test sets.
#
# 4.Next, to generate predictions will use the predict() method.
#
# 5.we will use predict_proba to generate probability estimates for each observations.
#
# 6.Fnally, compute and print the confusion matrix and classification report for the model.

# %% [markdown]
# To evaluate the model performance we have ROC curve. It is a way to visually evaluate model performance. After building the logistic regression model, we try to evaluate its performance by plotting an ROC curve. This can be done using the .predict_proba() method.
#
# ROC(Receiver Operating Characteristic)curve is an evaluation metric for binary classification problems, created by plotting the true positive rate (TPR) against the false positive rate (FPR) at various thresholds. It shows the trade-off between sensitivity (or TPR) and specificity (1 – FPR)

# %%
Parameters that needs to be specified before fitting a model, are called hyperparameters.
By Choosing the correct hyperparameters we can build a successful model.

When fitting different values of hypterparameter, it is better to use cross-validation along with train_test_split to avoid overfitting of the model

# %% [markdown]
# #### Data Preprocessing steps:
#
# 1. Handle missing data : drop or fill NaNs
# 2. Cleaning Datatypes for all features
# 3. Processing Categorical features to numerical values
# 4. Feature Engineering
# 5. Standardizing or Normalizing
# 6. Removing redundant or related features
# 7. Stratified Sampling / PCA (Dimensionality reduction)

# %% [markdown]
# 2.	Do the same as question 1 except for unsupervised learning models. Something that is necessary for many models is determining number, so specify how you determine the number of clusters for example. Apply this concept to any other algorithms it is relevant for.

# %% [markdown]
# 3.	Preprocess the customer data https://www.kaggle.com/carrie1/ecommerce-data . How are you handling nulls? What process(es) are you using to encode and normalize the data?

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("A:\launch_code_STL\Final_Homework\week-19\data.csv", sep=",", encoding="ISO-8859-1")
print(data.shape)
data.head()
# Out:
# (541909, 8)
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# when we import the data in csv format, we get different characters in the data that's when we should be using encoding.
# In this dataset encoding is used to convert string into byte string. so, to be able to pass non-ascii data, we are using
# encoding="ISO-8859-1".

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
# looking at the descriptive statistics of the data
data.describe (include='all').T
# Out:
#                 count unique                                 top    freq  \
# InvoiceNo      541909  25900                              573585    1114
# StockCode      541909   4070                              85123A    2313
# Description    540455   4223  WHITE HANGING HEART T-LIGHT HOLDER    2369
# Quantity     541909.0    NaN                                 NaN     NaN
# InvoiceDate    541909  23260                    10/31/2011 14:41    1114
# UnitPrice    541909.0    NaN                                 NaN     NaN
# CustomerID     406829   4372                               17841    7983
# Country        541909     38                      United Kingdom  495478
#
#                  mean         std       min   25%   50%   75%      max
# InvoiceNo         NaN         NaN       NaN   NaN   NaN   NaN      NaN
# StockCode         NaN         NaN       NaN   NaN   NaN   NaN      NaN
# Description       NaN         NaN       NaN   NaN   NaN   NaN      NaN
# Quantity      9.55225  218.081158  -80995.0   1.0   3.0  10.0  80995.0
# InvoiceDate       NaN         NaN       NaN   NaN   NaN   NaN      NaN
# UnitPrice    4.611114   96.759853 -11062.06  1.25  2.08  4.13  38970.0
# CustomerID        NaN         NaN       NaN   NaN   NaN   NaN      NaN
# Country           NaN         NaN       NaN   NaN   NaN   NaN      NaN

# %% [markdown]
# we can see there are missing values and NaN's for some features. Also, We see that there is a negative value as min in 'Quantity'

# %% [markdown]
# #### Data cleaning

# %%
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'], format="%m/%d/%Y %H:%M")
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom

# %% [markdown]
# #### Handling Missing Values

# %%
data.isnull().values.any()
# Out:
# True

# %%
data.isnull().sum()*100/data.shape[0]
# Out:
# InvoiceNo       0.000000
# StockCode       0.000000
# Description     0.268311
# Quantity        0.000000
# InvoiceDate     0.000000
# UnitPrice       0.000000
# CustomerID     24.926694
# Country         0.000000
# dtype: float64

# %% [markdown]
# we have two columns with missing values('Description', 'CustomerID')
# the 'CustomerID' column, is having almost 25% of the data missing and 'Description' column is hvaing 0.3% of the data missing.

# %%
# dropping null features:
data.dropna(inplace=True)

# %%
data.isnull().sum()*100/data.shape[0]
# Out:
# InvoiceNo      0.0
# StockCode      0.0
# Description    0.0
# Quantity       0.0
# InvoiceDate    0.0
# UnitPrice      0.0
# CustomerID     0.0
# Country        0.0
# dtype: float64

# %%
# Firstly i will create a new column as Amount according to the UnitPrice and Quantity purchased.
data['Amount'] = data['Quantity']*data['UnitPrice']
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Amount
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34

# %%
# Now, will create a new DataFrame with each unique customer and amount they have spent.This is like cluster them according 
# to Amount spent. 

each_customer = data.groupby('CustomerID')['Amount'].sum() #sum()adds up all the amounts and get a total for each CustomerID.
each_customer.reset_index()
# Out:
#      CustomerID   Amount
# 0         12346     0.00
# 1         12347  4310.00
# 2         12348  1797.24
# 3         12349  1757.55
# 4         12350   334.40
# ...         ...      ...
# 4367      18280   180.60
# 4368      18281    80.82
# 4369      18282   176.60
# 4370      18283  2094.88
# 4371      18287  1837.28
#
# [4372 rows x 2 columns]

# %%
# Next we can ckeck no. of times customer visited to store by using Invoice column

each_customer_freq = data.groupby('CustomerID')['InvoiceNo'].count()
each_customer_freq.reset_index()
# Out:
#      CustomerID  InvoiceNo
# 0         12346          2
# 1         12347        182
# 2         12348         31
# 3         12349         73
# 4         12350         17
# ...         ...        ...
# 4367      18280         10
# 4368      18281          7
# 4369      18282         13
# 4370      18283        756
# 4371      18287         70
#
# [4372 rows x 2 columns]

# %%
# Now we will merge the two DataFrames and store the info under customer_details
customer_details=pd.merge(each_customer_freq,each_customer,on='CustomerID')
customer_details.reset_index()
# Out:
#      CustomerID  InvoiceNo   Amount
# 0         12346          2     0.00
# 1         12347        182  4310.00
# 2         12348         31  1797.24
# 3         12349         73  1757.55
# 4         12350         17   334.40
# ...         ...        ...      ...
# 4367      18280         10   180.60
# 4368      18281          7    80.82
# 4369      18282         13   176.60
# 4370      18283        756  2094.88
# 4371      18287         70  1837.28
#
# [4372 rows x 3 columns]

# %%
# we can improve this by even getting more details like which customers have visited the store for long time. 
# By this we can cluster the customers who have not visited and can see the underlying pattren. To do this we use
# the column 'InvoiceDate' which contains the datetime with respect to each invoice. we have already converted 
# this column into datetime format.

# %%
max_date = max(data['InvoiceDate'])
data['recency'] = max_date - data['InvoiceDate']
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Amount  \
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom   20.34
#
#             recency
# 0 373 days 04:24:00
# 1 373 days 04:24:00
# 2 373 days 04:24:00
# 3 373 days 04:24:00
# 4 373 days 04:24:00

# %%
# groupby each customer and get minimun from the recency column, last seen customers

dates = data.groupby('CustomerID')['recency'].min()
dates=dates.reset_index()
dates.head()
# Out:
#   CustomerID           recency
# 0      12346 325 days 02:33:00
# 1      12347   1 days 20:58:00
# 2      12348  74 days 23:37:00
# 3      12349  18 days 02:59:00
# 4      12350 309 days 20:49:00

# %%
# we use dt.days of the datetime library to get only the days and remove the time
import datetime as dt
dates['recency'] = dates['recency'].dt.days
dates
# Out:
#      CustomerID  recency
# 0         12346      325
# 1         12347        1
# 2         12348       74
# 3         12349       18
# 4         12350      309
# ...         ...      ...
# 4367      18280      277
# 4368      18281      180
# 4369      18282        7
# 4370      18283        3
# 4371      18287       42
#
# [4372 rows x 2 columns]

# %%
# now, will try to merge this back to earlier 'customer_details' dataset
customer_details=pd.merge(customer_details, dates, on='CustomerID', how='inner')
customer_details
# Out:
#      CustomerID  InvoiceNo   Amount  recency
# 0         12346          2     0.00      325
# 1         12347        182  4310.00        1
# 2         12348         31  1797.24       74
# 3         12349         73  1757.55       18
# 4         12350         17   334.40      309
# ...         ...        ...      ...      ...
# 4367      18280         10   180.60      277
# 4368      18281          7    80.82      180
# 4369      18282         13   176.60        7
# 4370      18283        756  2094.88        3
# 4371      18287         70  1837.28       42
#
# [4372 rows x 4 columns]

# %%
# we can see the'Amount' column has many outliers, we need to get rid of them to get good clusters
# the quantile function
outlier_detection_x = customer_details.Amount.quantile(0.05)
outlier_detection_y = customer_details.Amount.quantile(0.95)

# To get the interquartile range for the above quantile function by subtracting 95 percentile with 5 percentile.
iqr = outlier_detection_y - outlier_detection_x

customer_details = customer_details[(customer_details['Amount']>=outlier_detection_x-1.5*iqr) & (customer_details['Amount']<=outlier_detection_y+1.5*iqr)]

# %%
outlier_detection_x = customer_details.InvoiceNo.quantile(0.05)
outlier_detection_y = customer_details.InvoiceNo.quantile(0.95)
iqr = outlier_detection_y - outlier_detection_x

customer_details = customer_details[(customer_details['InvoiceNo']>=outlier_detection_x-1.5*iqr) & (customer_details['InvoiceNo']<=outlier_detection_y+1.5*iqr)]

# %%
outlier_detection_x = customer_details.recency.quantile(0.05)
outlier_detection_y = customer_details.recency.quantile(0.95)
iqr = outlier_detection_y - outlier_detection_x

customer_details = customer_details[(customer_details['recency']>=outlier_detection_x-1.5*iqr) & (customer_details['recency']<=outlier_detection_y+1.5*iqr)]

# %% [markdown]
# #### Normalize the data

# %%
from sklearn.preprocessing import normalize
data_scaled = normalize(customer_details)
data_scaled = pd.DataFrame(data_scaled, columns=customer_details.columns)
print(data_scaled.head())
data_scaled.shape
# Out:
#    CustomerID  InvoiceNo    Amount   recency
# 0    0.999654   0.000162  0.000000  0.026315
# 1    0.944040   0.013916  0.329538  0.000076
# 2    0.989553   0.002484  0.144028  0.005930
# 3    0.990005   0.005852  0.140901  0.001443
# 4    0.999320   0.001376  0.027059  0.025003
# (4293, 4)

# %% [markdown]
# #### Rescaling the Attributes

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
scaled = sc.fit_transform(customer_details[['InvoiceNo', 'Amount', 'recency']])
scaled.shape
# Out:
# (4271, 3)

# %%
scaled_values = pd.DataFrame(scaled)
scaled_values.columns = ['InvoiceNo', 'Amount', 'recency']
scaled_values
# Out:
#       InvoiceNo    Amount   recency
# 0     -0.771795 -0.759639  2.295613
# 1      1.117217  1.916220 -0.910045
# 2     -0.467454  0.356175 -0.187782
# 3     -0.026685  0.331534 -0.741847
# 4     -0.614377 -0.552027  2.137309
# ...         ...       ...       ...
# 4266  -0.698333 -0.651673 -0.197676
# 4267  -0.687839 -0.647514  1.820701
# 4268  -0.719322 -0.709462  0.860982
# 4269  -0.656355 -0.649997 -0.850681
# 4270  -0.058168  0.381034 -0.504390
#
# [4271 rows x 3 columns]

# %% [markdown]
# 4.	Perform k-means on this dataset for customer segments. Customer segments help determine what types of people buy your product, which allows you to target more people like your usual customers. Should you look at all the data, or which subset of data should you use? What is the ideal number of clusters? Which approach did you use to find the ideal number of clusters and why?

# %% [markdown]
# ### K-Means Clustering

# %%
# # Import Normalizer
# from sklearn.preprocessing import Normalizer

# # Create a normalizer: normalizer
# normalizer = Normalizer()

# # Create a KMeans model with 10 clusters: kmeans
# kmeans = KMeans(n_clusters = 3)
# from sklearn.pipeline import make_pipeline
# # Make a pipeline chaining normalizer and kmeans: pipeline
# pipeline = make_pipeline(normalizer, kmeans)

# # Fit pipeline to the daily price movements
# pipeline.fit(clusters)

# %%
# Import KMeans
from sklearn.cluster import KMeans

scores=[]
for i in range(2,7):
    model = KMeans(n_clusters=i, max_iter=10, verbose=True)
    model.fit(data_scaled)
    scores.append(model.inertia_)
# Out:
# Initialization complete
# Iteration 0, inertia 39.958626545319184
# Iteration 1, inertia 23.898909547170664
# Iteration 2, inertia 20.12377240139295
# Iteration 3, inertia 18.484903874190117
# Iteration 4, inertia 17.96950048493342
# Iteration 5, inertia 17.662806378876745
# Iteration 6, inertia 17.53321956396359
# Iteration 7, inertia 17.489722379787978
# Iteration 8, inertia 17.47271037645702
# Iteration 9, inertia 17.465364143293336
# Initialization complete
# Iteration 0, inertia 18.901017357020514
# Iteration 1, inertia 17.816043803057337
# Iteration 2, inertia 17.588583159722596
# Iteration 3, inertia 17.514832403070184
# Iteration 4, inertia 17.478708997118957
# Iteration 5, inertia 17.471412778481444
# Iteration 6, inertia 17.465012511662497
# Iteration 7, inertia 17.46206286660823
# Iteration 8, inertia 17.46169850951341
# Iteration 9, inertia 17.46074705839108
# Initialization complete
# Iteration 0, inertia 34.131397229030604
# Iteration 1, inertia 18.309321420433758
# Iteration 2, inertia 17.9039054692364
# Iteration 3, inertia 17.63139571442119
# Iteration 4, inertia 17.528168635672067
# Iteration 5, inertia 17.48678026631039
# Iteration 6, inertia 17.469491746964483
# Iteration 7, inertia 17.464767434581734
# Iteration 8, inertia 17.460815184258095
# Iteration 9, inertia 17.459758101164166
# Converged at iteration 9: center shift 8.915013045426048e-08 within tolerance 3.0066394314211816e-07.
# Initialization complete
# Iteration 0, inertia 22.320814150668408
# Iteration 1, inertia 18.86225962645107
# Iteration 2, inertia 17.981257221454346
# Iteration 3, inertia 17.64180874944844
# Iteration 4, inertia 17.536255446518577
# Iteration 5, inertia 17.482818323283848
# Iteration 6, inertia 17.471412778481444
# Iteration 7, inertia 17.465012511662497
# Iteration 8, inertia 17.46206286660823
# Iteration 9, inertia 17.46169850951341
# Initialization complete
# Iteration 0, inertia 21.111184721200047
# Iteration 1, inertia 18.542462092685618
# Iteration 2, inertia 17.977110182267232
# Iteration 3, inertia 17.662806378876745
# Iteration 4, inertia 17.533219563963595
# Iteration 5, inertia 17.489722379787974
# Iteration 6, inertia 17.47271037645702
# Iteration 7, inertia 17.465364143293336
# Iteration 8, inertia 17.46168927211128
# Iteration 9, inertia 17.4599004202635
# Initialization complete
# Iteration 0, inertia 33.40249380582539
# Iteration 1, inertia 23.724703216407452
# Iteration 2, inertia 19.907295603784195
# Iteration 3, inertia 18.392277630356144
# Iteration 4, inertia 17.803466525653665
# Iteration 5, inertia 17.583796220305654
# Iteration 6, inertia 17.514832403070184
# Iteration 7, inertia 17.478708997118957
# Iteration 8, inertia 17.471412778481444
# Iteration 9, inertia 17.465012511662497
# Initialization complete
# Iteration 0, inertia 23.17901123734781
# Iteration 1, inertia 18.929823461123057
# Iteration 2, inertia 18.00559722753825
# Iteration 3, inertia 17.651036407639552
# Iteration 4, inertia 17.543059835198815
# Iteration 5, inertia 17.490019824431197
# Iteration 6, inertia 17.474366470009805
# Iteration 7, inertia 17.468820935042675
# Iteration 8, inertia 17.46229247599839
# Iteration 9, inertia 17.461698509513415
# Initialization complete
# Iteration 0, inertia 32.09780109239842
# Iteration 1, inertia 23.273768615116392
# Iteration 2, inertia 19.711675631643114
# Iteration 3, inertia 18.328376533552593
# Iteration 4, inertia 17.77407953529166
# Iteration 5, inertia 17.56981236594532
# Iteration 6, inertia 17.50548918793031
# Iteration 7, inertia 17.477889883277367
# Iteration 8, inertia 17.471412778481447
# Iteration 9, inertia 17.465012511662497
# Initialization complete
# Iteration 0, inertia 35.24004916120431
# Iteration 1, inertia 23.898909547170664
# Iteration 2, inertia 20.12377240139295
# Iteration 3, inertia 18.484903874190117
# Iteration 4, inertia 17.96950048493342
# Iteration 5, inertia 17.662806378876745
# Iteration 6, inertia 17.533219563963595
# Iteration 7, inertia 17.48972237978797
# Iteration 8, inertia 17.47271037645702
# Iteration 9, inertia 17.465364143293336
# Initialization complete
# Iteration 0, inertia 21.85946722173309
# Iteration 1, inertia 17.841990885490937
# Iteration 2, inertia 17.593462430740896
# Iteration 3, inertia 17.516327887016107
# Iteration 4, inertia 17.480916749227564
# Iteration 5, inertia 17.46804811651061
# Iteration 6, inertia 17.462776131158215
# Iteration 7, inertia 17.460137917726108
# Iteration 8, inertia 17.45971049932607
# Converged at iteration 8: strict convergence.
# Initialization complete
# Iteration 0, inertia 10.634282519097049
# Iteration 1, inertia 9.010686291762546
# Iteration 2, inertia 8.660799811618485
# Iteration 3, inertia 8.496964542189946
# Iteration 4, inertia 8.440578590202444
# Iteration 5, inertia 8.424783484588819
# Iteration 6, inertia 8.420592673165928
# Iteration 7, inertia 8.4200722460492
# Converged at iteration 7: center shift 4.898087073110455e-08 within tolerance 3.0066394314211816e-07.
# Initialization complete
# Iteration 0, inertia 10.629218922450221
# Iteration 1, inertia 8.811871715222622
# Iteration 2, inertia 8.689323089857913
# Iteration 3, inertia 8.639068700242271
# Iteration 4, inertia 8.595682117776374
# Iteration 5, inertia 8.557146640708858
# Iteration 6, inertia 8.503032005299046
# Iteration 7, inertia 8.455817606801247
# Iteration 8, inertia 8.443558717718902
# Iteration 9, inertia 8.43082061781876
# Initialization complete
# Iteration 0, inertia 11.745695458314465
# Iteration 1, inertia 9.513339306538292
# Iteration 2, inertia 8.993372383728847
# Iteration 3, inertia 8.702044233094476
# Iteration 4, inertia 8.514979342169779
# Iteration 5, inertia 8.447900373347252
# Iteration 6, inertia 8.425145152646408
# Iteration 7, inertia 8.42072727083653
# Iteration 8, inertia 8.4200722460492
# Converged at iteration 8: center shift 4.898087073109831e-08 within tolerance 3.0066394314211816e-07.
# Initialization complete
# Iteration 0, inertia 13.970207010792183
# Iteration 1, inertia 8.791898642600597
# Iteration 2, inertia 8.559865158704655
# Iteration 3, inertia 8.454398234783419
# Iteration 4, inertia 8.427687679156511
# Iteration 5, inertia 8.421236317340203
# Iteration 6, inertia 8.420123852890878
# Converged at iteration 6: center shift 1.1000532652954156e-07 within tolerance 3.0066394314211816e-07.
# Initialization complete
# Iteration 0, inertia 9.542091412198367
# Iteration 1, inertia 8.48828099911267
# Iteration 2, inertia 8.423406604917764
# Iteration 3, inertia 8.421179204072274
# Iteration 4, inertia 8.420660715435453
# Converged at iteration 4: center shift 4.6473468166617944e-08 within tolerance 3.0066394314211816e-07.
# Initialization complete
# Iteration 0, inertia 11.88010347391382
# Iteration 1, inertia 9.134797017729374
# Iteration 2, inertia 8.708008887140094
# Iteration 3, inertia 8.583701698933073
# Iteration 4, inertia 8.507582802169864
# Iteration 5, inertia 8.465874282818849
# Iteration 6, inertia 8.448250368924118
# Iteration 7, inertia 8.436226490648803
# Iteration 8, inertia 8.429225874634463
# Iteration 9, inertia 8.424233684563282
# Initialization complete
# Iteration 0, inertia 14.823266170762814
# Iteration 1, inertia 9.669113794695567
# Iteration 2, inertia 8.852733929887169
# Iteration 3, inertia 8.675991114677341
# Iteration 4, inertia 8.617799352482772
# Iteration 5, inertia 8.565661342409363
# Iteration 6, inertia 8.511439009051166
# Iteration 7, inertia 8.460073417145873
# Iteration 8, inertia 8.444949889304954
# Iteration 9, inertia 8.432984177653966
# Initialization complete
# Iteration 0, inertia 12.078555530138628
# Iteration 1, inertia 9.924245386858908
# Iteration 2, inertia 9.420586094861434
# Iteration 3, inertia 9.033633223657564
# Iteration 4, inertia 8.756565891167664
# Iteration 5, inertia 8.564022390664768
# Iteration 6, inertia 8.45850636834967
# Iteration 7, inertia 8.42944323226832
# Iteration 8, inertia 8.421654262878066
# Iteration 9, inertia 8.420123852890878
# Converged at iteration 9: center shift 1.1000532652954216e-07 within tolerance 3.0066394314211816e-07.
# Initialization complete
# Iteration 0, inertia 11.932568157556235
# Iteration 1, inertia 9.126186044255524
# Iteration 2, inertia 8.765945404124944
# Iteration 3, inertia 8.533673830060717
# Iteration 4, inertia 8.45043850847397
# Iteration 5, inertia 8.426519250452104
# Iteration 6, inertia 8.421059712542533
# Iteration 7, inertia 8.420123852890878
# Converged at iteration 7: center shift 1.1000532652953363e-07 within tolerance 3.0066394314211816e-07.
# Initialization complete
# Iteration 0, inertia 10.137764782540833
# Iteration 1, inertia 9.079109197220678
# Iteration 2, inertia 8.772360562056596
# Iteration 3, inertia 8.570435326685132
# Iteration 4, inertia 8.460212867857
# Iteration 5, inertia 8.4298864314211
# Iteration 6, inertia 8.422132432352624
# Iteration 7, inertia 8.420250203434133
# Converged at iteration 7: center shift 1.9705009087183989e-07 within tolerance 3.0066394314211816e-07.
# Initialization complete
# Iteration 0, inertia 7.183866064966905
# Iteration 1, inertia 5.862212750342597
# Iteration 2, inertia 5.511619588397869
# Iteration 3, inertia 5.355809241484589
# Iteration 4, inertia 5.28281996711992
# Iteration 5, inertia 5.237603409267092
# Iteration 6, inertia 5.199387169764264
# Iteration 7, inertia 5.175812850450456
# Iteration 8, inertia 5.164415680683495
# Iteration 9, inertia 5.154744512029651
# Initialization complete
# Iteration 0, inertia 6.338985080379005
# Iteration 1, inertia 5.124469195044606
# Iteration 2, inertia 5.081455615909117
# Iteration 3, inertia 5.078297329408364
# Converged at iteration 3: center shift 2.367940372701914e-07 within tolerance 3.0066394314211816e-07.
# Initialization complete
# Iteration 0, inertia 7.286288745363565
# Iteration 1, inertia 6.26451458747874
# Iteration 2, inertia 5.943467099219495
# Iteration 3, inertia 5.717902161618957
# Iteration 4, inertia 5.572605506210266
# Iteration 5, inertia 5.4678371430889445
# Iteration 6, inertia 5.3730417805534385
# Iteration 7, inertia 5.307346962660029
# Iteration 8, inertia 5.2367333224809265
# Iteration 9, inertia 5.194619396811614
# Initialization complete
# Iteration 0, inertia 6.485862912931853
# Iteration 1, inertia 5.5093103050782055
# Iteration 2, inertia 5.327369234225731
# Iteration 3, inertia 5.246568321076371
# Iteration 4, inertia 5.204643703244737
# Iteration 5, inertia 5.1744336550673635
# Iteration 6, inertia 5.150520296518321
# Iteration 7, inertia 5.129731307789313
# Iteration 8, inertia 5.112878142383263
# Iteration 9, inertia 5.094166058724662
# Initialization complete
# Iteration 0, inertia 6.9920956423995095
# Iteration 1, inertia 5.748634028299043
# Iteration 2, inertia 5.346924522643098
# Iteration 3, inertia 5.213073134793061
# Iteration 4, inertia 5.170003421814456
# Iteration 5, inertia 5.15267902834824
# Iteration 6, inertia 5.139979950351422
# Iteration 7, inertia 5.128019488068623
# Iteration 8, inertia 5.119271372097826
# Iteration 9, inertia 5.115219658392968
# Initialization complete
# Iteration 0, inertia 6.937590240023635
# Iteration 1, inertia 5.306268192868434
# Iteration 2, inertia 5.09572214455132
# Iteration 3, inertia 5.077832962046966
# Iteration 4, inertia 5.075235647809043
# Iteration 5, inertia 5.073949117558689
# Converged at iteration 5: center shift 7.470601777346537e-08 within tolerance 3.0066394314211816e-07.
# Initialization complete
# Iteration 0, inertia 6.489868355910843
# Iteration 1, inertia 5.699438376782999
# Iteration 2, inertia 5.4407497734247965
# Iteration 3, inertia 5.332848248210383
# Iteration 4, inertia 5.281683862947425
# Iteration 5, inertia 5.243244094492448
# Iteration 6, inertia 5.203158114054235
# Iteration 7, inertia 5.179641024874366
# Iteration 8, inertia 5.1667246035757834
# Iteration 9, inertia 5.157203494364061
# Initialization complete
# Iteration 0, inertia 5.947586628958156
# Iteration 1, inertia 5.412876835352543
# Iteration 2, inertia 5.322000463261394
# Iteration 3, inertia 5.276170872275638
# Iteration 4, inertia 5.234592782195668
# Iteration 5, inertia 5.199831581989768
# Iteration 6, inertia 5.176247321134273
# Iteration 7, inertia 5.165556856650796
# Iteration 8, inertia 5.156540346246059
# Iteration 9, inertia 5.1477922303033985
# Initialization complete
# Iteration 0, inertia 7.253497661669051
# Iteration 1, inertia 5.56866431215996
# Iteration 2, inertia 5.283490963672793
# Iteration 3, inertia 5.229533187762522
# Iteration 4, inertia 5.194072145209044
# Iteration 5, inertia 5.173129417272363
# Iteration 6, inertia 5.16393106214816
# Iteration 7, inertia 5.155483064684643
# Iteration 8, inertia 5.1469824724099675
# Iteration 9, inertia 5.139494547602445
# Initialization complete
# Iteration 0, inertia 5.8671396364506645
# Iteration 1, inertia 5.15467959493624
# Iteration 2, inertia 5.113095433374073
# Iteration 3, inertia 5.090921674084195
# Iteration 4, inertia 5.082062404594224
# Iteration 5, inertia 5.0783816310292895
# Iteration 6, inertia 5.076581167856761
# Iteration 7, inertia 5.075044778232694
# Iteration 8, inertia 5.074117799193333
# Iteration 9, inertia 5.073960964107437
# Converged at iteration 9: center shift 8.670975053155451e-08 within tolerance 3.0066394314211816e-07.
# Initialization complete
# Iteration 0, inertia 5.301870481676424
# Iteration 1, inertia 3.902201044700712
# Iteration 2, inertia 3.776043627153658
# Iteration 3, inertia 3.703475308419826
# Iteration 4, inertia 3.637838585203733
# Iteration 5, inertia 3.56584620424567
# Iteration 6, inertia 3.512536364356122
# Iteration 7, inertia 3.4826271689695303
# Iteration 8, inertia 3.468594061623396
# Iteration 9, inertia 3.4606357376584933
# Initialization complete
# Iteration 0, inertia 4.806403733786399
# Iteration 1, inertia 3.7131818966111707
# Iteration 2, inertia 3.535602460006674
# Iteration 3, inertia 3.4798926525466705
# Iteration 4, inertia 3.4662837466146033
# Iteration 5, inertia 3.4597592415330136
# Iteration 6, inertia 3.4551974881722907
# Iteration 7, inertia 3.451567508141094
# Iteration 8, inertia 3.4446021027578677
# Iteration 9, inertia 3.435389641122816
# Initialization complete
# Iteration 0, inertia 5.929780873252717
# Iteration 1, inertia 3.6262510793056033
# Iteration 2, inertia 3.4942845298981915
# Iteration 3, inertia 3.4646860127760646
# Iteration 4, inertia 3.45309366292098
# Iteration 5, inertia 3.446855473008482
# Iteration 6, inertia 3.4434918756615867
# Iteration 7, inertia 3.4415064224154364
# Iteration 8, inertia 3.440835806033535
# Iteration 9, inertia 3.4403174249776916
# Initialization complete
# Iteration 0, inertia 4.102360227518409
# Iteration 1, inertia 3.6087736987773367
# Iteration 2, inertia 3.5154133984156957
# Iteration 3, inertia 3.478185985141345
# Iteration 4, inertia 3.455112752554297
# Iteration 5, inertia 3.4395427274062094
# Iteration 6, inertia 3.4303195367199315
# Iteration 7, inertia 3.4257963555633313
# Iteration 8, inertia 3.4237096080334473
# Iteration 9, inertia 3.4225209927981686
# Initialization complete
# Iteration 0, inertia 4.562113727555087
# Iteration 1, inertia 3.5695409517058874
# Iteration 2, inertia 3.472124684712044
# Iteration 3, inertia 3.453884005829869
# Iteration 4, inertia 3.44861219394832
# Iteration 5, inertia 3.4434089659482963
# Iteration 6, inertia 3.4343432234935114
# Iteration 7, inertia 3.4305130200550447
# Iteration 8, inertia 3.4292343596121806
# Iteration 9, inertia 3.4264435371410746
# Initialization complete
# Iteration 0, inertia 4.709619606998914
# Iteration 1, inertia 3.9408112056424605
# Iteration 2, inertia 3.8184095854139435
# Iteration 3, inertia 3.731397940850887
# Iteration 4, inertia 3.6544967117626235
# Iteration 5, inertia 3.587825001285367
# Iteration 6, inertia 3.529070322532834
# Iteration 7, inertia 3.492584219441399
# Iteration 8, inertia 3.47476831012171
# Iteration 9, inertia 3.4636444041286865
# Initialization complete
# Iteration 0, inertia 4.2380868277760415
# Iteration 1, inertia 3.5527651571483125
# Iteration 2, inertia 3.486928007718217
# Iteration 3, inertia 3.461374725992832
# Iteration 4, inertia 3.4490160136894366
# Iteration 5, inertia 3.4411219453362394
# Iteration 6, inertia 3.43375262203168
# Iteration 7, inertia 3.430702510050602
# Iteration 8, inertia 3.4290305739241864
# Iteration 9, inertia 3.426348660576489
# Initialization complete
# Iteration 0, inertia 3.89462932623503
# Iteration 1, inertia 3.4748296171597572
# Iteration 2, inertia 3.4427000474246006
# Iteration 3, inertia 3.430838445925961
# Iteration 4, inertia 3.425856954476914
# Iteration 5, inertia 3.423933084169783
# Iteration 6, inertia 3.4226282723489754
# Converged at iteration 6: center shift 1.9015720363931897e-07 within tolerance 3.0066394314211816e-07.
# Initialization complete
# Iteration 0, inertia 4.22758834034097
# Iteration 1, inertia 3.486733785961899
# Iteration 2, inertia 3.459253798856648
# Iteration 3, inertia 3.4500869362935904
# Iteration 4, inertia 3.44619579079032
# Iteration 5, inertia 3.4450418548709365
# Iteration 6, inertia 3.443986678648075
# Iteration 7, inertia 3.4425827877608737
# Iteration 8, inertia 3.4405633553015
# Iteration 9, inertia 3.439807416296711
# Initialization complete
# Iteration 0, inertia 4.552789633445639
# Iteration 1, inertia 3.4891137360991458
# Iteration 2, inertia 3.4351046321101566
# Iteration 3, inertia 3.4278935629496066
# Iteration 4, inertia 3.4260569530853537
# Iteration 5, inertia 3.4253776723288976
# Iteration 6, inertia 3.425046456675126
# Iteration 7, inertia 3.424765079274866
# Iteration 8, inertia 3.4245144036528634
# Converged at iteration 8: center shift 1.6208485428418512e-07 within tolerance 3.0066394314211816e-07.
# Initialization complete
# Iteration 0, inertia 3.8694469453232636
# Iteration 1, inertia 2.6835036278343196
# Iteration 2, inertia 2.5497329964701994
# Iteration 3, inertia 2.497214659663728
# Iteration 4, inertia 2.4807262717284364
# Iteration 5, inertia 2.4741040993931596
# Iteration 6, inertia 2.4729092501060377
# Iteration 7, inertia 2.4717620620578233
# Iteration 8, inertia 2.47108491009446
# Converged at iteration 8: center shift 2.9589406769355446e-07 within tolerance 3.0066394314211816e-07.
# Initialization complete
# Iteration 0, inertia 3.0503548533023386
# Iteration 1, inertia 2.5921956650302125
# Iteration 2, inertia 2.52450224066306
# Iteration 3, inertia 2.501818548556025
# Iteration 4, inertia 2.4896210710627296
# Iteration 5, inertia 2.4836095807594614
# Iteration 6, inertia 2.4809830755078495
# Iteration 7, inertia 2.4791350575005047
# Iteration 8, inertia 2.4772609851955707
# Iteration 9, inertia 2.474815995140659
# Initialization complete
# Iteration 0, inertia 3.080051270093356
# Iteration 1, inertia 2.8405807995940573
# Iteration 2, inertia 2.8015469118675327
# Iteration 3, inertia 2.7755439199413874
# Iteration 4, inertia 2.761373375696779
# Iteration 5, inertia 2.752033505253442
# Iteration 6, inertia 2.7450323983464266
# Iteration 7, inertia 2.7381206250196026
# Iteration 8, inertia 2.731091499532457
# Iteration 9, inertia 2.722641648266549
# Initialization complete
# Iteration 0, inertia 2.9024422201008897
# Iteration 1, inertia 2.5267239738558844
# Iteration 2, inertia 2.503705546931199
# Iteration 3, inertia 2.497447083976
# Iteration 4, inertia 2.4928580986018276
# Iteration 5, inertia 2.4910033297407326
# Iteration 6, inertia 2.4883729353981443
# Iteration 7, inertia 2.4860925614509792
# Iteration 8, inertia 2.483920241389785
# Iteration 9, inertia 2.480928760004204
# Initialization complete
# Iteration 0, inertia 3.1238845019814985
# Iteration 1, inertia 2.5239922814004827
# Iteration 2, inertia 2.485457104412233
# Iteration 3, inertia 2.47879952252883
# Iteration 4, inertia 2.4774578896664883
# Iteration 5, inertia 2.4756732838151887
# Iteration 6, inertia 2.473767797347162
# Iteration 7, inertia 2.472471344327419
# Iteration 8, inertia 2.471994127774861
# Converged at iteration 8: center shift 8.215861460151951e-08 within tolerance 3.0066394314211816e-07.
# Initialization complete
# Iteration 0, inertia 3.146365851019347
# Iteration 1, inertia 2.604048969610786
# Iteration 2, inertia 2.576505331552887
# Iteration 3, inertia 2.551795336195072
# Iteration 4, inertia 2.530622746570151
# Iteration 5, inertia 2.517278705117666
# Iteration 6, inertia 2.510009011061714
# Iteration 7, inertia 2.5013679233322073
# Iteration 8, inertia 2.49571535572314
# Iteration 9, inertia 2.490958903908065
# Initialization complete
# Iteration 0, inertia 3.611121385159361
# Iteration 1, inertia 2.584543516972822
# Iteration 2, inertia 2.510464657449138
# Iteration 3, inertia 2.49349713832271
# Iteration 4, inertia 2.4873763325579583
# Iteration 5, inertia 2.482713511333024
# Iteration 6, inertia 2.479735979156067
# Iteration 7, inertia 2.4776880081161283
# Iteration 8, inertia 2.476166025431281
# Iteration 9, inertia 2.474752361828737
# Initialization complete
# Iteration 0, inertia 3.618000223014549
# Iteration 1, inertia 3.013100183866623
# Iteration 2, inertia 2.867354690582133
# Iteration 3, inertia 2.8037671246751916
# Iteration 4, inertia 2.7668707727751327
# Iteration 5, inertia 2.7496063803996322
# Iteration 6, inertia 2.7417707413125947
# Iteration 7, inertia 2.7359259605815986
# Iteration 8, inertia 2.731701398371343
# Iteration 9, inertia 2.728960955739801
# Initialization complete
# Iteration 0, inertia 3.488454497930809
# Iteration 1, inertia 2.7404100170564476
# Iteration 2, inertia 2.6459646133932466
# Iteration 3, inertia 2.6075023128503427
# Iteration 4, inertia 2.592299841648182
# Iteration 5, inertia 2.5717319032760937
# Iteration 6, inertia 2.5495120095604293
# Iteration 7, inertia 2.5302223123654195
# Iteration 8, inertia 2.518019327948762
# Iteration 9, inertia 2.5092213179405536
# Initialization complete
# Iteration 0, inertia 4.260798854242176
# Iteration 1, inertia 3.2449253637673743
# Iteration 2, inertia 2.930197411433505
# Iteration 3, inertia 2.776943041041869
# Iteration 4, inertia 2.744493264221268
# Iteration 5, inertia 2.72726950707597
# Iteration 6, inertia 2.703118621222301
# Iteration 7, inertia 2.6714692963769826
# Iteration 8, inertia 2.660232429423456
# Iteration 9, inertia 2.649611499920912

# %%
len(scores)
# Out:
# 5

# %%
plt.plot(range(2,7,1), scores)
plt.xticks(ticks=range(2,7))
plt.show()

# %%
from sklearn.metrics import silhouette_score


for i in range(2,7):
    model = KMeans(n_clusters=i, max_iter=10).fit(data_scaled)
    cluster_labels=model.labels_
    silhouette_avg=silhouette_score(data_scaled,cluster_labels)
    print('For n_clusters{} the silhouette scores is {}'.format(i,silhouette_avg))
# Out:
# For n_clusters2 the silhouette scores is 0.7615708444600608
# For n_clusters3 the silhouette scores is 0.6943246828438847
# For n_clusters4 the silhouette scores is 0.6344063802738964
# For n_clusters5 the silhouette scores is 0.5910860906892192
# For n_clusters6 the silhouette scores is 0.5729139803643926

# %%
model = KMeans(n_clusters=3, max_iter=40).fit(data_scaled)
clusters = model.labels_

# %%
customer_details['Cluster']=clusters
customer_details
# Out:
#      CustomerID  InvoiceNo   Amount  recency  Cluster
# 0         12346          2     0.00      325        0
# 1         12347        182  4310.00        1        1
# 2         12348         31  1797.24       74        1
# 3         12349         73  1757.55       18        1
# 4         12350         17   334.40      309        0
# ...         ...        ...      ...      ...      ...
# 4366      18278          9   173.90       73        0
# 4367      18280         10   180.60      277        0
# 4368      18281          7    80.82      180        0
# 4369      18282         13   176.60        7        0
# 4371      18287         70  1837.28       42        0
#
# [4293 rows x 5 columns]

# %%
# Clusters based on Amount Spent

# %%
sns.boxplot(x='Cluster', y='Amount', data=customer_details)
plt.show()

# %%
sns.boxplot(x='Cluster', y='InvoiceNo', data=customer_details)
plt.show()

# %%
sns.boxplot(x='Cluster', y='recency', data=customer_details)
plt.show()

# %% [markdown]
# 5.	Perform hierarchical clustering for customer segments. What is the ideal number of clusters? Which approach did you use to find the ideal number of clusters and why?

# %% [markdown]
# Hierarchical clustering: Process of creating clusters that are predetermined from top to bottom

# %% [markdown]
# Every column begins in a separate cluster, the two closest clusters are merged, at each step and
# continues until all the columns are in a single cluster.This is "agglomerative" hierarchical clustering

# %%
# import libraries
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram

mergings = linkage(data_scaled, method='complete', metric='euclidean')
dendrogram(mergings,
           labels = clusters,
           leaf_rotation=90,
           leaf_font_size=6)
plt.show()

# %%
# Single Linkage:
mergings = linkage(scaled_values, method='single', metric='euclidean')
dendrogram(mergings,
           labels = clusters,
           leaf_rotation=90,
           leaf_font_size=6)
plt.show()

# %%
mergings = linkage(scaled_values, method='average', metric='euclidean')
dendrogram(mergings,
           labels = clusters,
           leaf_rotation=90,
           leaf_font_size=6)
plt.show()

# %%
#### Cutting the Dendrogram based on K

# %%
# 3 clusters
from scipy import cluster
cluster_labels =  cluster.hierarchy.cut_tree(mergings, n_clusters=3).reshape(-1, )
cluster_labels
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
customer_details['Cluster_labels'] = cluster_labels
customer_details.head()
# Out:
#   CustomerID  InvoiceNo   Amount  recency  Cluster  Cluster_labels
# 0      12346          2     0.00      325        2               0
# 1      12347        182  4310.00        1        0               0
# 2      12348         31  1797.24       74        1               0
# 3      12349         73  1757.55       18        1               0
# 4      12350         17   334.40      309        2               0

# %% [markdown]
# With the help of boxplots we can visualize the clusters formed on different features:

# %%
# Plot Cluster vs Amount

sns.boxplot(x='Cluster_labels', y='Amount', data=customer_details)
# Out:
# <AxesSubplot:xlabel='Cluster_labels', ylabel='Amount'>

# %%
# Plot Cluster vs Amount

sns.boxplot(x='Cluster_labels', y='InvoiceNo', data=customer_details)
# Out:
# <AxesSubplot:xlabel='Cluster_labels', ylabel='InvoiceNo'>

# %%
# Plot Cluster vs Amount

sns.boxplot(x='Cluster_labels', y='recency', data=customer_details)
# Out:
# <AxesSubplot:xlabel='Cluster_labels', ylabel='recency'>

# %%
# Perform the necessary imports
import pandas as pd
from scipy.cluster.hierarchy import fcluster

# Use fcluster to extract labels: labels
labels = fcluster(mergings, 6, criterion='distance')

# Create a DataFrame with labels and varieties as columns: df
df = pd.DataFrame({'labels': labels, 'recency': clusters})

# Create crosstab: ct
ct = pd.crosstab(df['labels'], df['recency'])

# Display ct
print(ct)

# %%
from scipy.cluster.hierarchy import linkage
mergings = linkage(scaled_values, method='complete')

from scipy.cluster.hierarchy import fcluster
labels = fcluster(mergings, 6, criterion='distance')

print(labels)
# Out:
# [1 3 1 ... 1 1 1]

# %%
# Import TSNE
from sklearn.manifold import TSNE

# Create a TSNE instance: model
model = TSNE(learning_rate=200)

# Apply fit_transform to samples: tsne_features
tsne_features = model.fit_transform(scaled_values)

# Select the 0th feature: xs
xs = tsne_features[:,0]

# Select the 1st feature: ys
ys = tsne_features[:,1]

# Scatter plot, coloring by variety_numbers
plt.scatter(xs, ys, c=clusters)
plt.show()
# Out:
# C:\Users\rsagu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %% [markdown]
# 6.	Compare the results of 4 and 5. Which approach do you think is best? Why?

# %% [markdown]
# ![UnSupervised%20learning%20in%20ML.jpg](attachment:UnSupervised%20learning%20in%20ML.jpg)
