# %% [markdown]
# # Week-22 In-class Activity

# %% [markdown]
# 1. Use Splinter and/or Beautiful Soup to scrape mercadolibre.com.mx or soundcloud.com
# or tripadvisor.com. You must programmatically click a link from the front page to go to
# another page of interest to you and then select at least 5 items from that page. The 5
# items must be stored in a data structure that makes sense (dictionary, list, etc).

# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests
from pprint import pprint

# %%
url = 'https://www.mercadolibre.com.mx/'
page=requests.get(url)
page
# Out:
# <Response [200]>

# %%
soup = bs(page.text,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es-MX">
#  <head>
#   <link href="https://www.google-analytics.com" rel="preconnect"/>
#   <link href="https://www.google.com" rel="preconnect"/>
#   <link href="https://data.mercadolibre.com" rel="preconnect"/>
#   <link href="https://http2.mlstatic.com" rel="preconnect"/>
#   <link href="https://stats.g.doubleclick.net" rel="preconnect"/>
#   <link href="https://analytics.mercadolibre.com.mx" rel="preconnect"/>
#   <link href="https://analytics.mercadolibre.com" rel="preconnect"/>
#   <link href="https://www.google.com.mx" rel="preconnect"/>
#   <script type="text/javascript">
# ...

# %%
print(soup.title)
# Out:
# <title>Mercado Libre México - Envíos Gratis en el día</title>

# %%
for i in soup.find_all('a', href = True):
    print(i['href'])
    if "www.mercadolibre.com.mx/internetmoneyrecords/flossin" in i['href']:
        nextpage = request.grt(i['href'])
        nextsoup = bs(nextpage.text, 'html.parser')
        
        print("next url title: ", nextsoup.find('title').string)
# Out:
# #root-app
# //www.mercadolibre.com.mx
# https://www.mercadolibre.com/jms/mlm/lgz/login?platform_id=ML&go=https%3A%2F%2Flistado.mercadolibre.com.mx%2F&loginType=explicit
# https://www.mercadolibre.com.mx/registration?confirmation_url=https%3A%2F%2Flistado.mercadolibre.com.mx%2F
# https://www.mercadolibre.com.mx#menu-user
# https://www.mercadolibre.com.mx/ofertas#menu-user
# https://www.mercadolibre.com.mx/gz/home/navigation#menu-user
# https://www.mercadolibre.com.mx/ayuda#menu-user
# https://www.mercadolibre.com.mx/supermercado#menu-user
# https://www.mercadolibre.com.mx/c/ropa-bolsas-y-calzado#menu-user
# https://www.mercadolibre.com.mx/mas-vendidos#menu-user
# https://www.mercadolibre.com.mx/ofertas/compra-internacional?forceType=home&showDeal=true&splinterLab=admin#menu-user
# https://www.mercadolibre.com.mx/tiendas-oficiales#menu-user
# https://www.mercadolibre.com.mx/categorias#menu-user
# https://www.mercadolibre.com.mx/resumen#menu-user
# ...

# %%
url = 'https://www.mercadolibre.com.mx/ofertas'
page=requests.get(url)
soup = bs(page.text,'html.parser')

div_prod = soup.find_all('div', class_='promotion-item__container')
# div_prod

# %%
Price_tracker=[]
for div in div_prod:
    price = div.find('span', class_='promotion-item__price').text
    item_title = div.find('p', class_='promotion-item__title')
    product_name = item_title.text
    product_price = {'item':product_name,'Price':price}
    Price_tracker.append(product_price)
        
df = pd.DataFrame(Price_tracker)
df
# Out:
#                                                  item       Price
# 0   Laptop Lenovo Ideapad D330-10igl  Mineral Gray...     $ 4,499
# 1   Xiaomi Mi 11 Lite 5g Dual Sim 128 Gb Negro Tru...     $ 6,299
# 2   Xiaomi Mi Smart Band 6 1.56  Caja De  Plástico...       $ 799
# 3        Poco M4 Pro 5g Power Black 6gb Ram 128gb Rom     $ 4,849
# 4   Xiaomi Mi Watch 1.39  Caja De  Polímero Reforz...     $ 2,099
# 5   Colchón Restonic King Size Ortopedico Envio Gr...     $ 4,590
# 6        Localizador Rastreador Gps Auto Tkstar Tk905     $ 99769
# 7   Xtreme Pc Intel Core I5 10400 16gb Ssd 120gb 3...  $ 10,42930
# 8   Xiaomi Redmi K40 Gaming Edition Dual Sim 256 G...     $ 9,899
# 9   Nintendo Switch Oled 64gb Standard Color  Blan...     $ 9,349
# 10  Concentrador De Oxigeno 7 Litros Domestico Por...     $ 6,799
# 11  Amazon Echo Dot 3rd Gen Con Asistente Virtual ...       $ 768
# 12                  Audífonos Inalámbricos F9-5 Negro       $ 164
# ...

# %% [markdown]
# 2. Share with your group how web scraping worked on the website and link you chose.
# Compare it with others. List the site you chose and two observations about parsing the
# website. Indicate if this was the same or different for the sites chosen by others

# %% [markdown]
# I choose to scrape the mercadolibre.com.mx site. It's a supermarket website with images and text of the items but the
# containers in which they are stored had so many features that it took a while to find what I was looking for.

# %% [markdown]
# First, I choose the url to get to the page I wanted.  Then I worked through the items on the page, if we hover over the item,
# we get some info about it and we can drill down into the name of the item and stuff like that. we need to drill down in
# the divs to get to the info we want and just picked a category of interest and then scraped those items on the page,
# in this case it's a mix of items like laptops, smart watch, mobile phones, etc.,

# %% [markdown]
# Another strange thing I discovered is that the site kept changing at the end of the url to a filtered list that was
# likely based on my previous clicks. I had to be sure that the root of the website was working in my code.

# %% [markdown]
# Some of my groupmates choose to take soundcloud.com website. One difficulty they have in extracting information from the label.
# Another difficulty was extracting a url embedded in a larger string.
