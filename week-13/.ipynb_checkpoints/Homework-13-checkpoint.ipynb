# %% [markdown]
# # Homework-13

# %% [markdown]
# 1.	Download the dataset here: https://www.kaggle.com/sohier/calcofi and create one DataFrame for the bottle file and another for the cast file. Perform preprocessing on this dataset. You do not need to do all six types of preprocessing we discussed. For this dataset, 2-3 is all you need

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
import operator


low_memory=False
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn import linear_model as lm

# %%
bottle_df = pd.read_csv("bottle.csv", index_col=False, dtype='unicode')
cast_df = pd.read_csv('cast.csv', dtype='unicode')

# %%
bottle_df = pd.read_csv("bottle.csv", index_col=False, dtype='unicode')
bottle_df.head()
# Out:
#   Cst_Cnt Btl_Cnt       Sta_ID                                Depth_ID Depthm  \
# 0       1       1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3      0
# 1       1       2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3      8
# 2       1       3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7     10
# 3       1       4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3     19
# 4       1       5  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7     20
#
#      T_degC    Salnty O2ml_L    STheta O2Sat  ... R_PHAEO R_PRES R_SAMP DIC1  \
# 0  10.50000  33.44000    NaN  25.64900   NaN  ...     NaN      0    NaN  NaN
# 1  10.46000  33.44000    NaN  25.65600   NaN  ...     NaN      8    NaN  NaN
# 2  10.46000  33.43700    NaN  25.65400   NaN  ...     NaN     10    NaN  NaN
# 3  10.45000  33.42000    NaN  25.64300   NaN  ...     NaN     19    NaN  NaN
# 4  10.45000  33.42100    NaN  25.64300   NaN  ...     NaN     20    NaN  NaN
#
#   DIC2  TA1  TA2  pH2  pH1 DIC Quality Comment
# 0  NaN  NaN  NaN  NaN  NaN                 NaN
# 1  NaN  NaN  NaN  NaN  NaN                 NaN
# 2  NaN  NaN  NaN  NaN  NaN                 NaN
# 3  NaN  NaN  NaN  NaN  NaN                 NaN
# 4  NaN  NaN  NaN  NaN  NaN                 NaN
#
# [5 rows x 74 columns]

# %%
bottle_df = pd.read_csv("bottle.csv", index_col=False)

# Below two columns are of mixed type:
# 47: IncTim
# 73: DIC Quality Comment
# Out:
# C:\Users\rsagu\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (47,73) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
bottle_df = pd.read_csv("bottle.csv", index_col=False, low_memory=False )

# %%
bottle_df.shape
# Out:
# (864863, 74)

# %%
bottle_df.dtypes
# Out:
# Cst_Cnt                  int64
# Btl_Cnt                  int64
# Sta_ID                  object
# Depth_ID                object
# Depthm                   int64
#                         ...
# TA1                    float64
# TA2                    float64
# pH2                    float64
# pH1                    float64
# DIC Quality Comment     object
# Length: 74, dtype: object

# %%
categorical_data = bottle_df.select_dtypes("object")
numerical_data = bottle_df.select_dtypes("number")

# %%
categorical_data.head()
# Out:
#         Sta_ID                                Depth_ID IncTim  \
# 0  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3    NaN
# 1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3    NaN
# 2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7    NaN
# 3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3    NaN
# 4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7    NaN
#
#   DIC Quality Comment
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
numerical_data.head()
# Out:
#    Cst_Cnt  Btl_Cnt  Depthm  T_degC  Salnty  O2ml_L  STheta  O2Sat  \
# 0        1        1       0   10.50  33.440     NaN  25.649    NaN
# 1        1        2       8   10.46  33.440     NaN  25.656    NaN
# 2        1        3      10   10.46  33.437     NaN  25.654    NaN
# 3        1        4      19   10.45  33.420     NaN  25.643    NaN
# 4        1        5      20   10.45  33.421     NaN  25.643    NaN
#
#    Oxy_µmol/Kg  BtlNum  ...  R_CHLA  R_PHAEO  R_PRES  R_SAMP  DIC1  DIC2  TA1  \
# 0          NaN     NaN  ...     NaN      NaN       0     NaN   NaN   NaN  NaN
# 1          NaN     NaN  ...     NaN      NaN       8     NaN   NaN   NaN  NaN
# 2          NaN     NaN  ...     NaN      NaN      10     NaN   NaN   NaN  NaN
# 3          NaN     NaN  ...     NaN      NaN      19     NaN   NaN   NaN  NaN
# 4          NaN     NaN  ...     NaN      NaN      20     NaN   NaN   NaN  NaN
#
#    TA2  pH2  pH1
# 0  NaN  NaN  NaN
# 1  NaN  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  NaN  NaN
# 4  NaN  NaN  NaN
#
# [5 rows x 70 columns]

# %%
numerical_data.isnull().sum(axis=0)

# To have more data for analyses purpose, i would drop all the columns where the sum of null values in a column is greater
# than 5000
# Out:
# Cst_Cnt         0
# Btl_Cnt         0
# Depthm          0
# T_degC      10963
# Salnty      47354
#             ...
# DIC2       864639
# TA1        862779
# TA2        864629
# pH2        864853
# pH1        864779
# Length: 70, dtype: int64

# %%
# Extract 2 columns 'T_degC','Salnty' for pure and better showing
df = bottle_df[['T_degC','Salnty']]

# And called again
df.columns = ['Temperature', 'Salinity']

# %%
df = df[:][:500]      # lets take limit for speed regression calculating
df.head()
# Out:
#   Temperature  Salinity
# 0    10.50000  33.44000
# 1    10.46000  33.44000
# 2    10.46000  33.43700
# 3    10.45000  33.42000
# 4    10.45000  33.42100

# %%
# see how many null values we have

df.isnull().sum()
# Out:
# Temperature    1
# Salinity       6
# dtype: int64

# %%
# Drop NaN or missing input numbers

df.fillna(method='ffill', inplace=True)

# %%
# Features Salinity and Temperature are chosen

X = np.array(df['Salinity']).reshape(-1, 1).astype(float)
y = np.array(df['Temperature']).reshape(-1, 1).astype(float)

# %%
# Split data as %20 is test and %80 is train set

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

lin_df = LinearRegression()  
lin_df.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin_df.predict(X_test)                                     # Predict Linear Model
accuracy_score = lin_df.score(X_test, y_test)                       # Accuracy score
print("Linear Regression Model Accuracy Score: " + "{:.1%}".format(accuracy_score))
# Out:
# Linear Regression Model Accuracy Score: 82.7%

# %%
from sklearn.metrics import mean_squared_error,r2_score

print("R2 value: " +"{:.3}".format(r2_score(y_test, y_pred)))
print("Mean Squared Error: " +"{:.3}".format(mean_squared_error(y_test, y_pred)))
# Out:
# R2 value: 0.827
# Mean Squared Error: 1.43

# %%
correlation_mat = df.corr()
try:
    sns.heatmap(correlation_mat, annot = True)
except ValueError:  
    pass

plt.title("Correlation matrix ")
plt.xlabel("Salinity")
plt.ylabel("Temperature")
plt.show()

# %%
# Finally draw figure of Linear Regression Model

plt.scatter(X_test, y_test, color='green')
plt.plot(X_test, y_pred, color='blue')
plt.title("Linear Regression Model")
plt.xlabel("Salinity")
plt.ylabel("Temperature")
plt.show()

# %%
# As Salinity increasing Temperature is decreasing.

# %%
dataSet.describe()
# Out:
#           T_degC    Salnty
# count     853900    817509
# unique     13847     14602
# top     9.100000  33.58000
# freq        1115      3953

# %%
dataSet.isnull().sum()
# Out:
# T_degC    10963
# Salnty    47354
# dtype: int64

# %%
dataSet = dataSet.dropna()

# %%
dataSet.isnull().sum()
# Out:
# T_degC    0
# Salnty    0
# dtype: int64

# %%
dataSet.astype(float)
# Out:
#         T_degC   Salnty
# 0       10.500  33.4400
# 1       10.460  33.4400
# 2       10.460  33.4370
# 3       10.450  33.4200
# 4       10.450  33.4210
# ...        ...      ...
# 864858  18.744  33.4083
# 864859  18.744  33.4083
# 864860  18.692  33.4150
# 864861  18.161  33.4062
# 864862  17.533  33.3880
#
# [864863 rows x 2 columns]

# %%
dataSet["T_degC"].corr(bottle_df["Salnty"]).head()

# %%
# Finding correlation using bottle columns 
data = bottle_df[["Depthm", "T_degC", "Salnty", "O2ml_L", "PO4q", "SiO3qu","NO3q","NH3q","NO2q"]]
correlation = data.corr(method='pearson')
correlation.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#  Depth_ID = [Century]-[YY][MM][ShipCode]-etc
#  19-4903CR-HY-060-0930-05400560-0020A-7
bottle_df['Year'] = (bottle_df['Depth_ID'].str.split('-', expand=True)[0] + \
                bottle_df['Depth_ID'].str.split('-', expand=True)[1]). \
                map(lambda x: str(x)[:4])
bottle_df['Month'] = (bottle_df['Depth_ID'].str.split('-', expand=True)[1]). \
                 map(lambda x: str(x)[2:4])
                 
bottle_df[['Depth_ID','Year','Month']].head(10)
# Out:
#                                  Depth_ID  Year Month
# 0  19-4903CR-HY-060-0930-05400560-0000A-3  1949    03
# 1  19-4903CR-HY-060-0930-05400560-0008A-3  1949    03
# 2  19-4903CR-HY-060-0930-05400560-0010A-7  1949    03
# 3  19-4903CR-HY-060-0930-05400560-0019A-3  1949    03
# 4  19-4903CR-HY-060-0930-05400560-0020A-7  1949    03
# 5  19-4903CR-HY-060-0930-05400560-0030A-7  1949    03
# 6  19-4903CR-HY-060-0930-05400560-0039A-3  1949    03
# 7  19-4903CR-HY-060-0930-05400560-0050A-7  1949    03
# 8  19-4903CR-HY-060-0930-05400560-0058A-3  1949    03
# 9  19-4903CR-HY-060-0930-05400560-0075A-7  1949    03

# %%
drop_cols = ['Cst_Cnt', 'Btl_Cnt', 'Sta_ID', 'Depth_ID', 'Depthm','Year','Month']
df_norm = bottle_df.drop(drop_cols, axis=1)  #  data for normalization
df_scale = df_norm.copy(deep=True)    #  backup data

# %%
# Data cleaning
# checking for Nulls/Duplicates

# %%
# removing duplicates 
bottle_df.drop_duplicates()
# Out:
#        Cst_Cnt Btl_Cnt       Sta_ID                                Depth_ID  \
# 0            1       1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
# 1            1       2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3
# 2            1       3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7
# 3            1       4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3
# 4            1       5  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7
# ...        ...     ...          ...                                     ...
# 864858   34404  864859  093.4 026.4  20-1611SR-MX-310-2239-09340264-0000A-7
# 864859   34404  864860  093.4 026.4  20-1611SR-MX-310-2239-09340264-0002A-3
# 864860   34404  864861  093.4 026.4  20-1611SR-MX-310-2239-09340264-0005A-3
# 864861   34404  864862  093.4 026.4  20-1611SR-MX-310-2239-09340264-0010A-3
# 864862   34404  864863  093.4 026.4  20-1611SR-MX-310-2239-09340264-0015A-3
#
#        Depthm    T_degC    Salnty    O2ml_L    STheta     O2Sat  ...  \
# 0           0  10.50000  33.44000       NaN  25.64900       NaN  ...
# 1           8  10.46000  33.44000       NaN  25.65600       NaN  ...
# 2          10  10.46000  33.43700       NaN  25.65400       NaN  ...
# 3          19  10.45000  33.42000       NaN  25.64300       NaN  ...
# 4          20  10.45000  33.42100       NaN  25.64300       NaN  ...
# ...       ...       ...       ...       ...       ...       ...  ...
# 864858      0  18.74400  33.40830  5.805000  23.87055  108.7400  ...
# 864859      2  18.74400  33.40830  5.805000  23.87072  108.7400  ...
# 864860      5  18.69200  33.41500  5.796000  23.88911  108.4600  ...
# 864861     10  18.16100  33.40620  5.816000  24.01426  107.7400  ...
# 864862     15  17.53300  33.38800  5.774000  24.15297  105.6600  ...
#
#          R_PHAEO R_PRES R_SAMP DIC1 DIC2  TA1  TA2  pH2  pH1  \
# 0            NaN      0    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1            NaN      8    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2            NaN     10    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3            NaN     19    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4            NaN     20    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...          ...    ...    ...  ...  ...  ...  ...  ...  ...
# 864858  0.180000      0    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 864859  0.180000      2      4  NaN  NaN  NaN  NaN  NaN  NaN
# 864860  0.180000      5      3  NaN  NaN  NaN  NaN  NaN  NaN
# 864861  0.310000     10      2  NaN  NaN  NaN  NaN  NaN  NaN
# 864862  0.610000     15      1  NaN  NaN  NaN  NaN  NaN  NaN
#
#        DIC Quality Comment
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 864858                 NaN
# 864859                 NaN
# 864860                 NaN
# 864861                 NaN
# 864862                 NaN
#
# [864863 rows x 74 columns]

# %%
# Displaying the count of null values per column
bottle_df.isnull().sum()
# Out:
# Cst_Cnt                     0
# Btl_Cnt                     0
# Sta_ID                      0
# Depth_ID                    0
# Depthm                      0
#                         ...
# TA1                    862779
# TA2                    864629
# pH2                    864853
# pH1                    864779
# DIC Quality Comment    864808
# Length: 74, dtype: int64

# %%
# Dropping the row having null value
bottle_df.dropna()
# Out:
# Empty DataFrame
# Columns: [Cst_Cnt, Btl_Cnt, Sta_ID, Depth_ID, Depthm, T_degC, Salnty, O2ml_L, STheta, O2Sat, Oxy_µmol/Kg, BtlNum, RecInd, T_prec, T_qual, S_prec, S_qual, P_qual, O_qual, SThtaq, O2Satq, ChlorA, Chlqua, Phaeop, Phaqua, PO4uM, PO4q, SiO3uM, SiO3qu, NO2uM, NO2q, NO3uM, NO3q, NH3uM, NH3q, C14As1, C14A1p, C14A1q, C14As2, C14A2p, C14A2q, DarkAs, DarkAp, DarkAq, MeanAs, MeanAp, MeanAq, IncTim, LightP, R_Depth, R_TEMP, R_POTEMP, R_SALINITY, R_SIGMA, R_SVA, R_DYNHT, R_O2, R_O2Sat, R_SIO3, R_PO4, R_NO3, R_NO2, R_NH4, R_CHLA, R_PHAEO, R_PRES, R_SAMP, DIC1, DIC2, TA1, TA2, pH2, pH1, DIC Quality Comment]
# Index: []
#
# [0 rows x 74 columns]
